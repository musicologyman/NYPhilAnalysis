# %%
import json

from pathlib import Path
from pprint import pprint

import toolz.curried as curried
from toolz.functoolz import pipe
from toolz.itertoolz import groupby

# %%
BASE_DIRECTORY = Path('./PerformanceHistory/Programs/json')

SEASONS = ['1960-61', '1961-62', '1962-63', '1963-64', '1964-65', '1965-66', 
           '1966-67', '1967-68', '1968-69', '1969-70', '1970-71', '1971-72', 
           '1972-73', '1973-74', '1974-75', '1975-76', '1976-77', '1977-78', 
           '1978-79', '1979-80', '1980-81']

# %%
def has_subscription_concert(program):
    for concert in program['concerts']:
        if concert['eventType'] == 'Subscription Season':
            return True
    return False

# %%
data_files = pipe(BASE_DIRECTORY.iterdir(),
                  curried.filter(lambda p: p.suffix == ".json"),
                  sorted)

for i, p in enumerate(data_files):
    print(f'{i:>3} {p.name}')
# Out:
#   0 1842-43_TO_1910-11.json
#   1 1911-12_TO_1919-20.json
#   2 1920-21_TO_1925-26.json
#   3 1926-27_TO_1931-32.json
#   4 1932-33_TO_1939-40.json
#   5 1940-41_TO_1946-47.json
#   6 1947-48_TO_1954-55.json
#   7 1955-56_TO_1962-63.json
#   8 1963-64_TO_1973-74.json
#   9 1974-75_TO_1983-84.json
#  10 1984-85_TO_1994-95.json
#  11 1995-96_TO_2003-04.json
#  12 2004-05_TO_2010-11.json
#  13 2011-12_TO_NOW.json
#  14 complete.json

# %%
all_programs = []
for i in range(0, 14):
    
    with data_files[i].open() as fp:
        print(f'Processing file {i:>2} "{data_files[i]}"')
        root = json.load(fp)
        all_programs = all_programs + root['programs']
# Out:
# Processing file  0 "PerformanceHistory/Programs/json/1842-43_TO_1910-11.json"
# Processing file  1 "PerformanceHistory/Programs/json/1911-12_TO_1919-20.json"
# Processing file  2 "PerformanceHistory/Programs/json/1920-21_TO_1925-26.json"
# Processing file  3 "PerformanceHistory/Programs/json/1926-27_TO_1931-32.json"
# Processing file  4 "PerformanceHistory/Programs/json/1932-33_TO_1939-40.json"
# Processing file  5 "PerformanceHistory/Programs/json/1940-41_TO_1946-47.json"
# Processing file  6 "PerformanceHistory/Programs/json/1947-48_TO_1954-55.json"
# Processing file  7 "PerformanceHistory/Programs/json/1955-56_TO_1962-63.json"
# Processing file  8 "PerformanceHistory/Programs/json/1963-64_TO_1973-74.json"
# Processing file  9 "PerformanceHistory/Programs/json/1974-75_TO_1983-84.json"
# Processing file 10 "PerformanceHistory/Programs/json/1984-85_TO_1994-95.json"
# Processing file 11 "PerformanceHistory/Programs/json/1995-96_TO_2003-04.json"
# Processing file 12 "PerformanceHistory/Programs/json/2004-05_TO_2010-11.json"
# Processing file 13 "PerformanceHistory/Programs/json/2011-12_TO_NOW.json"

# %%
all_subscription_programs = [p for p in all_programs 
                             if has_subscription_concert(p)]

# %%
len(all_subscription_programs)
# Out:
# 6611

# %%
with open('all_subscription_programs.json', mode='w') as fp:
    json.dump(all_subscription_programs, fp, indent=2)

# %%
# Now filter by season

all_programs_filtered = [p for p in all_programs if p['season'] in SEASONS]

# %%
with open('nyphil_subscription_programs_1960_1981.json', mode='w') as fp:
    json.dump(all_subscription_programs, fp, indent=2)

# %%
def has_works_by(program, composer_name):
    for work in program['works']:
        if 'composerName' in work and (work['composerName'].find(composer_name) > -1):
            return True
    return False

# %%
def get_programs_for_composer(composer_name):
    return [p for p in all_subscription_programs 
            if has_works_by(p, composer_name)]

def get_works_for_composer(program, composer_name):
    retval = {}
    for key in ['id', 'programID', 'season']:
        retval[key] = program[key]
    retval['works'] = {}
    for work in program['works']:
        if 'composer_name' in work and work['composer_name'].find(composer_name) > -1:
            retval['works'].append(work)
    return retval

# %%
programs = get_programs_for_composer('Stravinsky')
# programs_str = json.dumps(programs, indent=2)
print(len(programs))
print(programs_str)
# Out:
# 70
# [
#   {
#     "id": "7f1bc02f-1faa-4493-910e-78c70553c633-0.1",
#     "programID": "1346",
#     "orchestra": "New York Philharmonic",
#     "season": "1960-61",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Carnegie Hall",
#         "Date": "1960-10-02T04:00:00Z",
#         "Time": "3:00PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "52389*",
#         "composerName": "Beethoven,  Ludwig  van",
#         "workTitle": "LEONORE OVERTURE NO. 3, OP. 72B",
#         "conductorName": "Shapira, Elyakum",
#         "soloists": []
#       },
#       {
#         "ID": "53078*",
#         "composerName": "Schumann,  Robert",
#         "workTitle": "SYMPHONY NO. 4, D MINOR, OP. 120",
#         "conductorName": "Millar, Gregory",
#         "soloists": []
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "52644*",
#         "composerName": "Debussy,  Claude",
#         "workTitle": "PRELUDE A L'APRES-MIDI D'UN FAUNE (PRELUDE TO THE AFTERNOON OF A FAUN)",
#         "conductorName": "Stanger, Russell",
#         "soloists": []
#       },
#       {
#         "ID": "53624*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "FIREBIRD: SUITE (1919 VERSION)",
#         "conductorName": "Stanger, Russell",
#         "soloists": []
#       }
#     ]
#   },
#   {
#     "id": "c590f827-4df2-4683-82ca-c9bf434cd182-0.1",
#     "programID": "3432",
#     "orchestra": "New York Philharmonic",
#     "season": "1960-61",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Carnegie Hall",
#         "Date": "1961-02-02T05:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Carnegie Hall",
#         "Date": "1961-02-03T05:00:00Z",
#         "Time": "2:15PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Carnegie Hall",
#         "Date": "1961-02-05T05:00:00Z",
#         "Time": "3:00PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "52065*",
#         "composerName": "Haydn,  Franz  Joseph",
#         "workTitle": "SYMPHONY NO.  85, B FLAT MAJOR (LA REINE)",
#         "conductorName": "Wallenstein, Alfred",
#         "soloists": []
#       },
#       {
#         "ID": "1993*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "CONCERTO, VIOLIN, D MAJOR",
#         "conductorName": "Wallenstein, Alfred",
#         "soloists": [
#           {
#             "soloistName": "Zeitlin, Zvi",
#             "soloistInstrument": "Violin",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "52437*",
#         "composerName": "Beethoven,  Ludwig  van",
#         "workTitle": "SYMPHONY NO. 3 IN E FLAT MAJOR, OP. 55 (EROICA)",
#         "conductorName": "Wallenstein, Alfred",
#         "soloists": []
#       }
#     ]
#   },
#   {
#     "id": "618f8ebf-01a4-4695-b43a-7d709c719e54-0.1",
#     "programID": "384",
#     "orchestra": "New York Philharmonic",
#     "season": "1960-61",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Carnegie Hall",
#         "Date": "1961-03-09T05:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Carnegie Hall",
#         "Date": "1961-03-10T05:00:00Z",
#         "Time": "2:15PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Carnegie Hall",
#         "Date": "1961-03-12T05:00:00Z",
#         "Time": "3:00PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "50097*",
#         "composerName": "Hindemith,  Paul",
#         "workTitle": "CONCERT MUSIC, STRINGS AND BRASS, OP. 50",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": []
#       },
#       {
#         "ID": "52016*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "SYMPHONIE DE PSAUMES (SYMPHONY OF PSALMS)",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": [
#           {
#             "soloistName": "Schola Cantorum of NY",
#             "soloistInstrument": "Chorus",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "51570*",
#         "composerName": "Ravel,  Maurice",
#         "workTitle": "DAPHNIS AND CHLOE",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": [
#           {
#             "soloistName": "Schola Cantorum of NY",
#             "soloistInstrument": "Chorus",
#             "soloistRoles": "S"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "id": "6f73fd6f-de15-4236-8ed3-db2e2f27ab9e-0.1",
#     "programID": "4779",
#     "orchestra": "New York Philharmonic",
#     "season": "1960-61",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Carnegie Hall",
#         "Date": "1961-04-13T05:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Carnegie Hall",
#         "Date": "1961-04-14T05:00:00Z",
#         "Time": "2:15PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Carnegie Hall",
#         "Date": "1961-04-16T05:00:00Z",
#         "Time": "3:00PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "426*",
#         "composerName": "Mayuzumi,  Toshiro",
#         "workTitle": "BACCHANALE",
#         "conductorName": "Ozawa, Seiji",
#         "soloists": []
#       },
#       {
#         "ID": "3685*",
#         "composerName": "Brahms,  Johannes",
#         "workTitle": "CONCERTO, VIOLIN, D MAJOR, OP.77",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": [
#           {
#             "soloistName": "Francescatti, Zino",
#             "soloistInstrument": "Violin",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "53708*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "SACRE DU PRINTEMPS, LE",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": []
#       }
#     ]
#   },
#   {
#     "id": "d2c86442-a969-4bab-a494-8f79a81da478-0.1",
#     "programID": "673",
#     "orchestra": "New York Philharmonic",
#     "season": "1961-62",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Carnegie Hall",
#         "Date": "1961-12-07T05:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Carnegie Hall",
#         "Date": "1961-12-08T05:00:00Z",
#         "Time": "2:15PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Carnegie Hall",
#         "Date": "1961-12-09T05:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Carnegie Hall",
#         "Date": "1961-12-10T05:00:00Z",
#         "Time": "3:00PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "50616*",
#         "composerName": "Honegger,  Arthur",
#         "workTitle": "SYMPHONY NO. 2",
#         "conductorName": "Krips, Josef",
#         "soloists": []
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "3685*",
#         "composerName": "Brahms,  Johannes",
#         "workTitle": "CONCERTO, VIOLIN, D MAJOR, OP.77",
#         "conductorName": "Krips, Josef",
#         "soloists": [
#           {
#             "soloistName": "Spivakovsky, Tossy",
#             "soloistInstrument": "Violin",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "53624*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "FIREBIRD: SUITE (1919 VERSION)",
#         "conductorName": "Krips, Josef",
#         "soloists": []
#       }
#     ]
#   },
#   {
#     "id": "b6cdb693-cbf7-4404-9130-bbcfe775e4ff-0.1",
#     "programID": "7059",
#     "orchestra": "New York Philharmonic",
#     "season": "1961-62",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Carnegie Hall",
#         "Date": "1962-05-17T04:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Carnegie Hall",
#         "Date": "1962-05-18T04:00:00Z",
#         "Time": "2:15PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Carnegie Hall",
#         "Date": "1962-05-19T04:00:00Z",
#         "Time": "2:15PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Carnegie Hall",
#         "Date": "1962-05-20T04:00:00Z",
#         "Time": "3:00PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "52579*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "GREETING PRELUDE",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": []
#       },
#       {
#         "ID": "53636*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "FIREWORKS, OP.4",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": []
#       },
#       {
#         "ID": "51984*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "CAPRICCIO FOR PIANO AND ORCHESTRA",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": [
#           {
#             "soloistName": "Lipkin, Seymour",
#             "soloistInstrument": "Piano",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "313*",
#         "composerName": "Piston,  Walter",
#         "workTitle": "CONCERTO, VIOLIN, NO. 2",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": [
#           {
#             "soloistName": "Fuchs, Joseph",
#             "soloistInstrument": "Violin",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "51872*",
#         "composerName": "Brahms,  Johannes",
#         "workTitle": "SYMPHONY NO. 2 IN D MAJOR, OP. 73",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": []
#       }
#     ]
#   },
#   {
#     "id": "4c86c972-96a7-47b8-a9a4-4c3a48af40aa-0.1",
#     "programID": "3254",
#     "orchestra": "New York Philharmonic",
#     "season": "1962-63",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1962-09-26T04:00:00Z",
#         "Time": "8:30PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "99*",
#         "composerName": "Strauss,  Richard",
#         "workTitle": "FESTIVAL PRELUDE",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": [
#           {
#             "soloistName": "Biggs, E. Power",
#             "soloistInstrument": "Organ",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "2062*",
#         "composerName": "Haydn,  Franz  Joseph",
#         "workTitle": "SINFONIA CONCERTANTE, B-FLAT MAJOR, H. I:105",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": [
#           {
#             "soloistName": "Corigliano, John, Sr.",
#             "soloistInstrument": "Violin",
#             "soloistRoles": "A"
#           },
#           {
#             "soloistName": "Stern, Carl",
#             "soloistInstrument": "Cello",
#             "soloistRoles": "A"
#           },
#           {
#             "soloistName": "Gomberg, Harold",
#             "soloistInstrument": "Oboe",
#             "soloistRoles": "A"
#           },
#           {
#             "soloistName": "Zegler, Manuel",
#             "soloistInstrument": "Bassoon",
#             "soloistRoles": "A"
#           }
#         ]
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "853*",
#         "composerName": "Vivaldi,  Antonio",
#         "workTitle": "CONCERTO, VIOLINS (4),  B MINOR, RV 580",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": [
#           {
#             "soloistName": "Fuchs, Joseph",
#             "soloistInstrument": "Violin",
#             "soloistRoles": "S"
#           },
#           {
#             "soloistName": "Gullino, Frank",
#             "soloistInstrument": "Violin",
#             "soloistRoles": "S"
#           },
#           {
#             "soloistName": "Goldberg, Szymon",
#             "soloistInstrument": "Violin",
#             "soloistRoles": "S"
#           },
#           {
#             "soloistName": "Spivakovsky, Tossy",
#             "soloistInstrument": "Violin",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "955*",
#         "composerName": "Bach,  Johann  Sebastian",
#         "workTitle": "CON., HARPSICHORDS, (FOUR), BWV 1065, A MINOR",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": [
#           {
#             "soloistName": "Fleisher, Leon",
#             "soloistInstrument": "Piano",
#             "soloistRoles": "S"
#           },
#           {
#             "soloistName": "Frager, Malcolm",
#             "soloistInstrument": "Piano",
#             "soloistRoles": "S"
#           },
#           {
#             "soloistName": "Graffman, Gary",
#             "soloistInstrument": "Piano",
#             "soloistRoles": "S"
#           },
#           {
#             "soloistName": "Istomin, Eugene",
#             "soloistInstrument": "Piano",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "53708*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "SACRE DU PRINTEMPS, LE",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": []
#       }
#     ]
#   },
#   {
#     "id": "ba44e427-5722-4545-be4e-b09019c7d38a-0.1",
#     "programID": "1122",
#     "orchestra": "New York Philharmonic",
#     "season": "1963-64",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1963-10-17T04:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1963-10-18T04:00:00Z",
#         "Time": "2:15PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1963-10-19T04:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1963-10-20T04:00:00Z",
#         "Time": "3:00PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "53754*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "SYMPHONY IN C",
#         "conductorName": "Kosler, Zdenek",
#         "soloists": []
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "52016*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "SYMPHONIE DE PSAUMES (SYMPHONY OF PSALMS)",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": [
#           {
#             "soloistName": "Choral Art Society",
#             "soloistInstrument": "Chorus",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "51526*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "SYMPHONY IN THREE MOVEMENTS",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": []
#       }
#     ]
#   },
#   {
#     "id": "5282fbfb-a0ee-4f6f-9078-6ab4c9cf3367-0.1",
#     "programID": "168",
#     "orchestra": "New York Philharmonic",
#     "season": "1963-64",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1964-03-14T05:00:00Z",
#         "Time": "8:30PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "8856*1",
#         "composerName": "Glinka,  Mikhail",
#         "workTitle": "RUSLAN AND LUDMILA",
#         "movement": "Overture",
#         "conductorName": "Kostelanetz, Andre",
#         "soloists": []
#       },
#       {
#         "ID": "543*",
#         "composerName": "Prokofiev,  Sergei",
#         "workTitle": "STONE FLOWER, THE: WEDDING SUITE, OP. 126",
#         "conductorName": "Kostelanetz, Andre",
#         "soloists": []
#       },
#       {
#         "ID": "53624*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "FIREBIRD: SUITE (1919 VERSION)",
#         "conductorName": "Kostelanetz, Andre",
#         "soloists": []
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "2331*",
#         "composerName": "Rimsky-Korsakov,  Nikolai",
#         "workTitle": "SCHEHERAZADE, OP. 35",
#         "conductorName": "Kostelanetz, Andre",
#         "soloists": [
#           {
#             "soloistName": "Corigliano, John, Sr.",
#             "soloistInstrument": "Violin",
#             "soloistRoles": "A"
#           }
#         ]
#       },
#       {
#         "ID": "6029*",
#         "composerName": "Scott,  Cyril",
#         "workTitle": "LOTUS LAND (ORCH) (ARR. Unspecified)",
#         "conductorName": "Kostelanetz, Andre",
#         "soloists": []
#       },
#       {
#         "ID": "2156*2",
#         "composerName": "Shostakovich,  Dmitri",
#         "workTitle": "AGE OF GOLD, THE, OP. 22A: SUITE",
#         "movement": "Polka (Allegretto)",
#         "conductorName": "Kostelanetz, Andre",
#         "soloists": []
#       }
#     ]
#   },
#   {
#     "id": "77098706-6feb-4eb3-a35f-8493027dde4c-0.1",
#     "programID": "3410",
#     "orchestra": "New York Philharmonic",
#     "season": "1964-65",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1964-12-31T05:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1965-01-01T05:00:00Z",
#         "Time": "2:15PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1965-01-02T05:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1965-01-03T05:00:00Z",
#         "Time": "3:00PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "3448*1",
#         "composerName": "Salieri,  Antonio",
#         "workTitle": "AXUR RE D'ORMUS",
#         "movement": "Overture",
#         "conductorName": "Schippers, Thomas",
#         "soloists": []
#       },
#       {
#         "ID": "51502*",
#         "composerName": "Bizet,  Georges",
#         "workTitle": "SYMPHONY IN C MAJOR",
#         "conductorName": "Schippers, Thomas",
#         "soloists": []
#       },
#       {
#         "ID": "1141*",
#         "composerName": "Saint-Saens [Saint-Sa\u00ebns],  Camille",
#         "workTitle": "CONCERTO, PIANO, NO. 5, OP. 103, F MAJOR (EGYPTIAN)",
#         "conductorName": "Schippers, Thomas",
#         "soloists": [
#           {
#             "soloistName": "Darre (Darr\u00e9), Jeanne-Marie",
#             "soloistInstrument": "Piano",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "1702*16",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "PETRUSHKA (1947 VERSION)",
#         "movement": "I. Russian Dance",
#         "conductorName": "Schippers, Thomas",
#         "soloists": []
#       },
#       {
#         "ID": "1702*3",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "PETRUSHKA (1947 VERSION)",
#         "movement": "Scene II: Petrushka",
#         "conductorName": "Schippers, Thomas",
#         "soloists": []
#       },
#       {
#         "ID": "1702*6",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "PETRUSHKA (1947 VERSION)",
#         "movement": "Scene IV: The Shrove-Tide Fair (and the death of Petrushka)",
#         "conductorName": "Schippers, Thomas",
#         "soloists": []
#       }
#     ]
#   },
#   {
#     "id": "0a7f4543-6858-49fb-8d3f-587f851c368d-0.1",
#     "programID": "2384",
#     "orchestra": "New York Philharmonic",
#     "season": "1964-65",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1965-05-06T04:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1965-05-07T04:00:00Z",
#         "Time": "2:15PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1965-05-08T04:00:00Z",
#         "Time": "8:30PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "6280*",
#         "composerName": "Perry,  Julia",
#         "workTitle": "STUDY FOR ORCHESTRA [SHORT PIECE FOR ORCHESTRA]",
#         "conductorName": "Steinberg, William",
#         "soloists": []
#       },
#       {
#         "ID": "53727*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "SONG OF THE NIGHTINGALE",
#         "conductorName": "Steinberg, William",
#         "soloists": []
#       },
#       {
#         "ID": "30*",
#         "composerName": "Verdi,  Giuseppe",
#         "workTitle": "QUARTET, STRINGS, E MINOR",
#         "conductorName": "Steinberg, William",
#         "soloists": []
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "3163*",
#         "composerName": "Beethoven,  Ludwig  van",
#         "workTitle": "CONCERTO, PIANO, NO. 4, G MAJOR, OP. 58",
#         "conductorName": "Steinberg, William",
#         "soloists": [
#           {
#             "soloistName": "Cliburn, Van",
#             "soloistInstrument": "Piano",
#             "soloistRoles": "S"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "id": "42e59c25-50ee-4455-8131-7b5afb7dc4f7-0.1",
#     "programID": "2388",
#     "orchestra": "New York Philharmonic",
#     "season": "1964-65",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1965-05-09T04:00:00Z",
#         "Time": "3:00PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "6280*",
#         "composerName": "Perry,  Julia",
#         "workTitle": "STUDY FOR ORCHESTRA [SHORT PIECE FOR ORCHESTRA]",
#         "conductorName": "Steinberg, William",
#         "soloists": []
#       },
#       {
#         "ID": "53727*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "SONG OF THE NIGHTINGALE",
#         "conductorName": "Steinberg, William",
#         "soloists": []
#       },
#       {
#         "ID": "30*",
#         "composerName": "Verdi,  Giuseppe",
#         "workTitle": "QUARTET, STRINGS, E MINOR",
#         "conductorName": "Steinberg, William",
#         "soloists": []
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "2229*",
#         "composerName": "Bruch,  Max",
#         "workTitle": "CONCERTO, VIOLIN, NO. 1, G MINOR, OP.26",
#         "conductorName": "Steinberg, William",
#         "soloists": [
#           {
#             "soloistName": "Perlman, Itzhak",
#             "soloistInstrument": "Violin",
#             "soloistRoles": "S"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "id": "38556c61-c5a0-4443-b79e-00ae16875e7e-0.1",
#     "programID": "7361",
#     "orchestra": "New York Philharmonic",
#     "season": "1965-66",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1965-10-20T04:00:00Z",
#         "Time": "8:30PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "53178*",
#         "composerName": "Shostakovich,  Dmitri",
#         "workTitle": "SYMPHONY NO.  9, OP. 70",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": []
#       },
#       {
#         "ID": "1993*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "CONCERTO, VIOLIN, D MAJOR",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": [
#           {
#             "soloistName": "Buswell, James Oliver, IV",
#             "soloistInstrument": "Violin",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "51821*",
#         "composerName": "Saint-Saens [Saint-Sa\u00ebns],  Camille",
#         "workTitle": "SYMPHONY NO. 3 IN C MINOR, OP. 78 (ORGAN SYM.)",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": [
#           {
#             "soloistName": "Crozier, Catherine",
#             "soloistInstrument": "Organ",
#             "soloistRoles": "A"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "id": "cdaefd62-d665-4b42-bd73-00f805d72c97-0.1",
#     "programID": "3385",
#     "orchestra": "New York Philharmonic",
#     "season": "1965-66",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1966-04-14T05:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1966-04-15T05:00:00Z",
#         "Time": "2:15PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1966-04-16T05:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1966-04-18T05:00:00Z",
#         "Time": "7:30PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "2095*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "SYMPHONIES OF WIND INSTRUMENTS (1947 VERSION)",
#         "conductorName": "Foss, Lukas",
#         "soloists": []
#       },
#       {
#         "ID": "5988*",
#         "composerName": "Foss,  Lukas",
#         "workTitle": "ELYTRES",
#         "conductorName": "Foss, Lukas",
#         "soloists": [
#           {
#             "soloistName": "Corigliano, John, Sr.",
#             "soloistInstrument": "Violin",
#             "soloistRoles": "A"
#           },
#           {
#             "soloistName": "Gullino, Frank",
#             "soloistInstrument": "Violin",
#             "soloistRoles": "A"
#           },
#           {
#             "soloistName": "Baker, Julius",
#             "soloistInstrument": "Flute",
#             "soloistRoles": "A"
#           }
#         ]
#       },
#       {
#         "ID": "51067*",
#         "composerName": "Mozart,  Wolfgang  Amadeus",
#         "workTitle": "CONCERTO, PIANO NO. 24, C MINOR, K.491",
#         "conductorName": "Foss, Lukas",
#         "soloists": [
#           {
#             "soloistName": "Kirchner, Leon",
#             "soloistInstrument": "Piano",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "5979*",
#         "composerName": "Kilar,  Wojciech",
#         "workTitle": "RIFF 62",
#         "conductorName": "Foss, Lukas",
#         "soloists": []
#       },
#       {
#         "ID": "54130*",
#         "composerName": "Tchaikovsky,  Pyotr  Ilyich",
#         "workTitle": "FRANCESCA DA RIMINI, OP. 32",
#         "conductorName": "Foss, Lukas",
#         "soloists": []
#       }
#     ]
#   },
#   {
#     "id": "c041fb55-fd6c-4872-a615-f429ec039e69-0.1",
#     "programID": "5588",
#     "orchestra": "New York Philharmonic",
#     "season": "1966-67",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1967-06-28T04:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1967-06-30T04:00:00Z",
#         "Time": "8:30PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "51526*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "SYMPHONY IN THREE MOVEMENTS",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": []
#       },
#       {
#         "ID": "5886*",
#         "composerName": "Schuller,  Gunther",
#         "workTitle": "TRIPLUM",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": []
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "2214*",
#         "composerName": "Rachmaninoff,  Sergei",
#         "workTitle": "CONCERTO, PIANO, NO. 3, D MINOR, OP. 30",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": [
#           {
#             "soloistName": "Cliburn, Van",
#             "soloistInstrument": "Piano",
#             "soloistRoles": "S"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "id": "4044e241-5507-4c33-a0db-9f61d773642c-0.1",
#     "programID": "2159",
#     "orchestra": "New York Philharmonic",
#     "season": "1967-68",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1968-05-09T04:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1968-05-10T04:00:00Z",
#         "Time": "2:15PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1968-05-11T04:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1968-05-13T04:00:00Z",
#         "Time": "7:30PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "878*1",
#         "composerName": "Schumann,  Robert",
#         "workTitle": "MANFRED, OP.115",
#         "movement": "Overture",
#         "conductorName": "Schippers, Thomas",
#         "soloists": []
#       },
#       {
#         "ID": "52654*",
#         "composerName": "Debussy,  Claude",
#         "workTitle": "RHAPSODY FOR CLARINET AND ORCHESTRA",
#         "conductorName": "Schippers, Thomas",
#         "soloists": [
#           {
#             "soloistName": "Drucker, Stanley",
#             "soloistInstrument": "Clarinet",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "51526*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "SYMPHONY IN THREE MOVEMENTS",
#         "conductorName": "Schippers, Thomas",
#         "soloists": []
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "52453*",
#         "composerName": "Beethoven,  Ludwig  van",
#         "workTitle": "SYMPHONY NO. 7 IN A MAJOR, OP.92",
#         "conductorName": "Schippers, Thomas",
#         "soloists": []
#       }
#     ]
#   },
#   {
#     "id": "1c5e09c5-345a-4322-aef4-a5db332ad814-0.1",
#     "programID": "2690",
#     "orchestra": "New York Philharmonic",
#     "season": "1968-69",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1968-10-10T04:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1968-10-11T04:00:00Z",
#         "Time": "2:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1968-10-12T04:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1968-10-14T04:00:00Z",
#         "Time": "7:30PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "4056*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "AGON, BALLET FOR TWELVE DANCERS",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": []
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "3034*",
#         "composerName": "Berio,  Luciano",
#         "workTitle": "SINFONIA",
#         "conductorName": "Berio, Luciano",
#         "soloists": [
#           {
#             "soloistName": "Swingle Singers, The",
#             "soloistInstrument": "Ensemble",
#             "soloistRoles": "S"
#           },
#           {
#             "soloistName": "Legrand, Christiane",
#             "soloistInstrument": "Soprano",
#             "soloistRoles": "A"
#           },
#           {
#             "soloistName": "Baucomont, Jeanette",
#             "soloistInstrument": "Soprano",
#             "soloistRoles": "A"
#           },
#           {
#             "soloistName": "Meunier, Claudine",
#             "soloistInstrument": "Alto",
#             "soloistRoles": "A"
#           },
#           {
#             "soloistName": "Devos, Helene [H\u00e9l\u00e8ne]",
#             "soloistInstrument": "Alto",
#             "soloistRoles": "A"
#           },
#           {
#             "soloistName": "Swingle, Ward",
#             "soloistInstrument": "Tenor",
#             "soloistRoles": "A"
#           },
#           {
#             "soloistName": "Noves, Joseph",
#             "soloistInstrument": "Tenor",
#             "soloistRoles": "A"
#           },
#           {
#             "soloistName": "Germain, Jose",
#             "soloistInstrument": "Bass",
#             "soloistRoles": "A"
#           },
#           {
#             "soloistName": "Cussac, Jean",
#             "soloistInstrument": "Bass",
#             "soloistRoles": "A"
#           }
#         ]
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "3163*",
#         "composerName": "Beethoven,  Ludwig  van",
#         "workTitle": "CONCERTO, PIANO, NO. 4, G MAJOR, OP. 58",
#         "conductorName": "Bernstein, Leonard",
#         "soloists": [
#           {
#             "soloistName": "Istomin, Eugene",
#             "soloistInstrument": "Piano",
#             "soloistRoles": "S"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "id": "8d7a3605-0017-4063-bc6c-eb6619ccfed5-0.1",
#     "programID": "7014",
#     "orchestra": "New York Philharmonic",
#     "season": "1968-69",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1968-11-07T05:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1968-11-08T05:00:00Z",
#         "Time": "2:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1968-11-09T05:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1968-11-11T05:00:00Z",
#         "Time": "7:30PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "2451*",
#         "composerName": "Bach,  Johann  Sebastian",
#         "workTitle": "BRANDENBURG CONCERTO NO. 3 IN G MAJOR, BWV 1048",
#         "conductorName": "Davis, Colin",
#         "soloists": []
#       },
#       {
#         "ID": "53754*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "SYMPHONY IN C",
#         "conductorName": "Davis, Colin",
#         "soloists": []
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "52437*",
#         "composerName": "Beethoven,  Ludwig  van",
#         "workTitle": "SYMPHONY NO. 3 IN E FLAT MAJOR, OP. 55 (EROICA)",
#         "conductorName": "Davis, Colin",
#         "soloists": []
#       }
#     ]
#   },
#   {
#     "id": "a4a45aec-e5ec-4aae-99f7-c6fb897f7ef0-0.1",
#     "programID": "6061",
#     "orchestra": "New York Philharmonic",
#     "season": "1968-69",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1969-04-03T05:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1969-04-04T05:00:00Z",
#         "Time": "2:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1969-04-05T05:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1969-04-07T05:00:00Z",
#         "Time": "7:30PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "5285*",
#         "composerName": "Purcell,  Henry",
#         "workTitle": "FANTASY, 3 VIOLS IN D, Z. 732",
#         "conductorName": "Boulez, Pierre",
#         "soloists": []
#       },
#       {
#         "ID": "10065*",
#         "composerName": "Purcell,  Henry",
#         "workTitle": "FANTASY, 4 VIOLS IN F, Z. 737",
#         "conductorName": "Boulez, Pierre",
#         "soloists": []
#       },
#       {
#         "ID": "10069*",
#         "composerName": "Purcell,  Henry",
#         "workTitle": "FANTASY, 4 VIOLS IN E, Z. 741",
#         "conductorName": "Boulez, Pierre",
#         "soloists": []
#       },
#       {
#         "ID": "10063*",
#         "composerName": "Purcell,  Henry",
#         "workTitle": "FANTASY, 4 VIOLS IN G, Z. 735",
#         "conductorName": "Boulez, Pierre",
#         "soloists": []
#       },
#       {
#         "ID": "10075*",
#         "composerName": "Purcell,  Henry",
#         "workTitle": "IN NOMINE, 7 VIOLS, Z. 747",
#         "conductorName": "Boulez, Pierre",
#         "soloists": []
#       },
#       {
#         "ID": "2095*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "SYMPHONIES OF WIND INSTRUMENTS (1947 VERSION)",
#         "conductorName": "Boulez, Pierre",
#         "soloists": []
#       },
#       {
#         "ID": "52113*",
#         "composerName": "Webern,  Anton  von",
#         "workTitle": "SIX PIECES, ORCHESTRA, OP. 6",
#         "conductorName": "Boulez, Pierre",
#         "soloists": []
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "53708*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "SACRE DU PRINTEMPS, LE",
#         "conductorName": "Boulez, Pierre",
#         "soloists": []
#       }
#     ]
#   },
#   {
#     "id": "7f0969a9-0c60-49de-849a-d3ba2cc9b876-0.1",
#     "programID": "6078",
#     "orchestra": "New York Philharmonic",
#     "season": "1968-69",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1969-04-17T05:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1969-04-18T05:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1969-04-21T05:00:00Z",
#         "Time": "7:30PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "4865*",
#         "composerName": "Rossini,  Gioachino",
#         "workTitle": "SONATA A QUATTRO NO. 3, C MAJOR",
#         "conductorName": "Semkow, Georg (Jerzy)",
#         "soloists": []
#       },
#       {
#         "ID": "53656*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "JEU DE CARTES (CARD GAME)",
#         "conductorName": "Semkow, Georg (Jerzy)",
#         "soloists": []
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "50068*",
#         "composerName": "Tchaikovsky,  Pyotr  Ilyich",
#         "workTitle": "SYMPHONY NO. 5, E MINOR, OP. 64",
#         "conductorName": "Semkow, Georg (Jerzy)",
#         "soloists": []
#       }
#     ]
#   },
#   {
#     "id": "4e7a4f25-cbc0-468e-a1b0-1219ec5ad39d-0.1",
#     "programID": "3025",
#     "orchestra": "New York Philharmonic",
#     "season": "1968-69",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1969-05-01T04:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1969-05-02T04:00:00Z",
#         "Time": "2:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1969-05-03T04:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1969-05-05T04:00:00Z",
#         "Time": "7:30PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "416*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "PETRUSHKA (1911 VERSION)",
#         "conductorName": "Huybrechts, Francois",
#         "soloists": []
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "53676*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "OCTET",
#         "conductorName": "Mechkat, Farhad",
#         "soloists": []
#       },
#       {
#         "ID": "53640*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "FOUR ETUDES FOR ORCHESTRA (1929 VERSION)",
#         "conductorName": "Huybrechts, Francois",
#         "soloists": []
#       },
#       {
#         "ID": "53624*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "FIREBIRD: SUITE (1919 VERSION)",
#         "conductorName": "Mechkat, Farhad;  Huybrechts, Francois",
#         "soloists": []
#       }
#     ]
#   },
#   {
#     "id": "6111456e-d81f-4b0a-821e-fa08d568af59-0.1",
#     "programID": "7007",
#     "orchestra": "New York Philharmonic",
#     "season": "1969-70",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1970-03-12T05:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1970-03-14T05:00:00Z",
#         "Time": "8:30PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Philharmonic Hall",
#         "Date": "1970-03-16T05:00:00Z",
#         "Time": "7:30PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "52004*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "OEDIPUS REX",
#         "conductorName": "Abbado, Claudio",
#         "soloists": [
#           {
#             "soloistName": "Fairbanks, Douglas, Jr.",
#             "soloistInstrument": "Narrator",
#             "soloistRoles": "S"
#           },
#           {
#             "soloistName": "Troyanos, Tatiana",
#             "soloistInstrument": "Mezzo-Soprano",
#             "soloistRoles": "S"
#           },
#           {
#             "soloistName": "Hollweg, Werner",
#             "soloistInstrument": "Tenor",
#             "soloistRoles": "S"
#           },
#           {
#             "soloistName": "Jones, Robert",
#             "soloistInstrument": "Tenor",
#             "soloistRoles": "S"
#           },
#           {
#             "soloistName": "Estes, Simon",
#             "soloistInstrument": "Bass-Baritone",
#             "soloistRoles": "S"
#           },
#           {
#             "soloistName": "Michalski, Raymond",
#             "soloistInstrument": "Bass-Baritone",
#             "soloistRoles": "S"
#           },
#           {
#             "soloistName": "Camerata Singers, The",
#             "soloistInstrument": "Mens Chorus",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "3565*",
#         "composerName": "Musorgsky,  Modest",
#         "workTitle": "OEDIPUS IN ATHENS: CHORUS FOR THE TEMPLE SCENE",
#         "conductorName": "Abbado, Claudio",
#         "soloists": [
#           {
#             "soloistName": "Camerata Singers, The",
#             "soloistInstrument": "Chorus",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "3574*",
#         "composerName": "Musorgsky,  Modest",
#         "workTitle": "DESTRUCTION OF SENNACHERIB",
#         "conductorName": "Abbado, Claudio",
#         "soloists": [
#           {
#             "soloistName": "Camerata Singers, The",
#             "soloistInstrument": "Chorus",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "3578*1",
#         "composerName": "Musorgsky,  Modest",
#         "workTitle": "SALAMMB\u00d4",
#         "movement": "Chorus of the Priestesses",
#         "conductorName": "Abbado, Claudio",
#         "soloists": [
#           {
#             "soloistName": "Camerata Singers, The",
#             "soloistInstrument": "Chorus",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "3569*",
#         "composerName": "Musorgsky,  Modest",
#         "workTitle": "JOSHUA",
#         "conductorName": "Abbado, Claudio",
#         "soloists": [
#           {
#             "soloistName": "Camerata Singers, The",
#             "soloistInstrument": "Chorus",
#             "soloistRoles": "S"
#           },
#           {
#             "soloistName": "Crouch, Barbara",
#             "soloistInstrument": "Mezzo-Soprano",
#             "soloistRoles": "A"
#           }
#         ]
#       },
#       {
#         "ID": "53780*1",
#         "composerName": "Prokofiev,  Sergei",
#         "workTitle": "ROMEO AND JULIET: SUITE NO. 2, OP. 64TER",
#         "movement": "The Montagues and the Capulets",
#         "conductorName": "Abbado, Claudio",
#         "soloists": []
#       },
#       {
#         "ID": "53784*2",
#         "composerName": "Prokofiev,  Sergei",
#         "workTitle": "ROMEO AND JULIET: SUITE NO. 3, OP. 101",
#         "movement": "Morning Dance",
#         "conductorName": "Abbado, Claudio",
#         "soloists": []
#       },
#       {
#         "ID": "52159*7",
#         "composerName": "Prokofiev,  Sergei",
#         "workTitle": "ROMEO AND JULIET, OP. 64",
# ...
#         "Date": "1979-10-04T04:00:00Z",
#         "Time": "8:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1979-10-05T04:00:00Z",
#         "Time": "8:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1979-10-06T04:00:00Z",
#         "Time": "8:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1979-10-09T04:00:00Z",
#         "Time": "7:30PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "53754*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "SYMPHONY IN C",
#         "conductorName": "Leinsdorf, Erich",
#         "soloists": []
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "50606*",
#         "composerName": "Mozart,  Wolfgang  Amadeus",
#         "workTitle": "CONCERTO, PIANO NO. 17, G MAJOR, K.453",
#         "conductorName": "Leinsdorf, Erich",
#         "soloists": [
#           {
#             "soloistName": "Dichter, Misha",
#             "soloistInstrument": "Piano",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "9001*12",
#         "composerName": "Wagner,  Richard",
#         "workTitle": "WALKURE, DIE, WWV 86B",
#         "movement": "Ride of the Valkyries, Act III",
#         "conductorName": "Leinsdorf, Erich",
#         "soloists": []
#       },
#       {
#         "ID": "9001*5",
#         "composerName": "Wagner,  Richard",
#         "workTitle": "WALKURE, DIE, WWV 86B",
#         "movement": "Act III: Interlude, scenes ii-iii",
#         "conductorName": "Leinsdorf, Erich",
#         "soloists": []
#       },
#       {
#         "ID": "9001*10",
#         "composerName": "Wagner,  Richard",
#         "workTitle": "WALKURE, DIE, WWV 86B",
#         "movement": "Wotan's Farewell, Act III, scene iii",
#         "conductorName": "Leinsdorf, Erich",
#         "soloists": []
#       },
#       {
#         "ID": "9001*9",
#         "composerName": "Wagner,  Richard",
#         "workTitle": "WALKURE, DIE, WWV 86B",
#         "movement": "Magic Fire Music, Act III, scene iii",
#         "conductorName": "Leinsdorf, Erich",
#         "soloists": []
#       }
#     ]
#   },
#   {
#     "id": "358c5f27-e335-4c3a-b1a5-b737b9426e24-0.1",
#     "programID": "5082",
#     "orchestra": "New York Philharmonic",
#     "season": "1979-80",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1979-12-20T05:00:00Z",
#         "Time": "8:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1979-12-21T05:00:00Z",
#         "Time": "2:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1979-12-22T05:00:00Z",
#         "Time": "8:00PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "52016*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "SYMPHONIE DE PSAUMES (SYMPHONY OF PSALMS)",
#         "conductorName": "Levine, James",
#         "soloists": [
#           {
#             "soloistName": "New York Choral Artists",
#             "soloistInstrument": "Chorus",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "51322*",
#         "composerName": "Mozart,  Wolfgang  Amadeus",
#         "workTitle": "MASS, C MINOR, K.417A (OLD K.427), \"GREAT\"",
#         "conductorName": "Levine, James",
#         "soloists": [
#           {
#             "soloistName": "Battle, Kathleen",
#             "soloistInstrument": "Soprano",
#             "soloistRoles": "S"
#           },
#           {
#             "soloistName": "Ewing, Maria",
#             "soloistInstrument": "Mezzo-Soprano",
#             "soloistRoles": "S"
#           },
#           {
#             "soloistName": "Creech, Philip",
#             "soloistInstrument": "Tenor",
#             "soloistRoles": "S"
#           },
#           {
#             "soloistName": "Cheek, John",
#             "soloistInstrument": "Bass",
#             "soloistRoles": "S"
#           },
#           {
#             "soloistName": "New York Choral Artists",
#             "soloistInstrument": "Chorus",
#             "soloistRoles": "S"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "id": "2000d5b6-e26c-41fa-a8e4-999d9461718d-0.1",
#     "programID": "1358",
#     "orchestra": "New York Philharmonic",
#     "season": "1979-80",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1980-01-03T05:00:00Z",
#         "Time": "8:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1980-01-04T05:00:00Z",
#         "Time": "2:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1980-01-05T05:00:00Z",
#         "Time": "8:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1980-01-08T05:00:00Z",
#         "Time": "7:30PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "2369*",
#         "composerName": "Schoenberg,  Arnold",
#         "workTitle": "VERKLAERTE NACHT (TRANSFIGURED NIGHT), OP. 4",
#         "conductorName": "Mehta, Zubin",
#         "soloists": []
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "2095*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "SYMPHONIES OF WIND INSTRUMENTS (1947 VERSION)",
#         "conductorName": "Mehta, Zubin",
#         "soloists": []
#       },
#       {
#         "ID": "52502*",
#         "composerName": "Mendelssohn,  Felix",
#         "workTitle": "CONCERTO, VIOLIN, E MINOR, OP.64",
#         "conductorName": "Mehta, Zubin",
#         "soloists": [
#           {
#             "soloistName": "Mutter, Anne-Sophie",
#             "soloistInstrument": "Violin",
#             "soloistRoles": "S"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "id": "98b7a0c7-e563-4991-be10-b76b36e4ff2d-0.1",
#     "programID": "7112",
#     "orchestra": "New York Philharmonic",
#     "season": "1979-80",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1980-04-10T05:00:00Z",
#         "Time": "8:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1980-04-11T05:00:00Z",
#         "Time": "2:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1980-04-12T05:00:00Z",
#         "Time": "8:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1980-04-15T05:00:00Z",
#         "Time": "7:30PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "52332*",
#         "composerName": "Copland,  Aaron",
#         "workTitle": "QUIET CITY",
#         "conductorName": "Mehta, Zubin",
#         "soloists": [
#           {
#             "soloistName": "Smith, Philip",
#             "soloistInstrument": "Trumpet",
#             "soloistRoles": "A"
#           },
#           {
#             "soloistName": "Stacy, Thomas",
#             "soloistInstrument": "English Horn",
#             "soloistRoles": "A"
#           }
#         ]
#       },
#       {
#         "ID": "51125*",
#         "composerName": "Liszt,  Franz",
#         "workTitle": "MALEDICTION",
#         "conductorName": "Mehta, Zubin",
#         "soloists": [
#           {
#             "soloistName": "Lowenthal, Jerome",
#             "soloistInstrument": "Piano",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "51988*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "CONCERTO FOR PIANO AND WIND INSTRUMENTS",
#         "conductorName": "Mehta, Zubin",
#         "soloists": [
#           {
#             "soloistName": "Lowenthal, Jerome",
#             "soloistInstrument": "Piano",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "52429*",
#         "composerName": "Beethoven,  Ludwig  van",
#         "workTitle": "SYMPHONY NO. 1 IN C MAJOR, OP.21",
#         "conductorName": "Mehta, Zubin",
#         "soloists": []
#       }
#     ]
#   },
#   {
#     "id": "180061fb-5297-47a9-b74b-86ff33ddf6d0-0.1",
#     "programID": "7118",
#     "orchestra": "New York Philharmonic",
#     "season": "1979-80",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1980-04-17T05:00:00Z",
#         "Time": "8:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1980-04-18T05:00:00Z",
#         "Time": "2:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1980-04-19T05:00:00Z",
#         "Time": "8:00PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "51807*",
#         "composerName": "Brahms,  Johannes",
#         "workTitle": "ACADEMIC FESTIVAL OVERTURE, OP.80",
#         "conductorName": "Mehta, Zubin",
#         "soloists": []
#       },
#       {
#         "ID": "51526*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "SYMPHONY IN THREE MOVEMENTS",
#         "conductorName": "Mehta, Zubin",
#         "soloists": []
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "3252*",
#         "composerName": "Elgar,  Sir  Edward",
#         "workTitle": "CONCERTO, VIOLIN, B MINOR, OP.61",
#         "conductorName": "Mehta, Zubin",
#         "soloists": [
#           {
#             "soloistName": "Zukerman, Pinchas",
#             "soloistInstrument": "Violin",
#             "soloistRoles": "S"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "id": "948b1725-bb15-4313-8f25-0b453e473591-0.1",
#     "programID": "7128",
#     "orchestra": "New York Philharmonic",
#     "season": "1979-80",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1980-04-22T05:00:00Z",
#         "Time": "7:30PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "51014*",
#         "composerName": "Barber,  Samuel",
#         "workTitle": "ESSAY NO. 3, OP.47",
#         "conductorName": "Mehta, Zubin",
#         "soloists": []
#       },
#       {
#         "ID": "51526*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "SYMPHONY IN THREE MOVEMENTS",
#         "conductorName": "Mehta, Zubin",
#         "soloists": []
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "50247*",
#         "composerName": "Brahms,  Johannes",
#         "workTitle": "CONCERTO, VIOLIN AND CELLO, OP. 102 (DOUBLE)",
#         "conductorName": "Mehta, Zubin",
#         "soloists": [
#           {
#             "soloistName": "Zukerman, Pinchas",
#             "soloistInstrument": "Violin",
#             "soloistRoles": "S"
#           },
#           {
#             "soloistName": "Harrell, Lynn",
#             "soloistInstrument": "Cello",
#             "soloistRoles": "S"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "id": "684d3e12-cc21-46c5-a19f-8307dd5d5570-0.1",
#     "programID": "7132",
#     "orchestra": "New York Philharmonic",
#     "season": "1979-80",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1980-04-24T05:00:00Z",
#         "Time": "8:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1980-04-25T05:00:00Z",
#         "Time": "2:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1980-04-26T05:00:00Z",
#         "Time": "8:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1980-04-29T04:00:00Z",
#         "Time": "7:30PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "51948*",
#         "composerName": "Strauss,  Richard",
#         "workTitle": "DON QUIXOTE, OP. 35",
#         "conductorName": "Mehta, Zubin",
#         "soloists": [
#           {
#             "soloistName": "Munroe, Lorne",
#             "soloistInstrument": "Cello",
#             "soloistRoles": "S"
#           },
#           {
#             "soloistName": "Greitzer, Sol",
#             "soloistInstrument": "Viola",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "51526*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "SYMPHONY IN THREE MOVEMENTS",
#         "conductorName": "Mehta, Zubin",
#         "soloists": []
#       },
#       {
#         "ID": "53215*",
#         "composerName": "Dvorak,  Anton\u00edn",
#         "workTitle": "CARNIVAL OVERTURE, OP.92",
#         "conductorName": "Mehta, Zubin",
#         "soloists": []
#       }
#     ]
#   },
#   {
#     "id": "143982c3-0961-4dd5-833b-e948a89417b5-0.1",
#     "programID": "4657",
#     "orchestra": "New York Philharmonic",
#     "season": "1980-81",
#     "concerts": [
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1980-10-30T05:00:00Z",
#         "Time": "8:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1980-10-31T05:00:00Z",
#         "Time": "2:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1980-11-01T05:00:00Z",
#         "Time": "8:00PM"
#       },
#       {
#         "eventType": "Subscription Season",
#         "Location": "Manhattan, NY",
#         "Venue": "Avery Fisher Hall",
#         "Date": "1980-11-04T05:00:00Z",
#         "Time": "7:30PM"
#       }
#     ],
#     "works": [
#       {
#         "ID": "53727*",
#         "composerName": "Stravinsky,  Igor",
#         "workTitle": "SONG OF THE NIGHTINGALE",
#         "conductorName": "Conlon, James",
#         "soloists": []
#       },
#       {
#         "ID": "51051*",
#         "composerName": "Liszt,  Franz",
#         "workTitle": "CONCERTO, PIANO, NO. 2, A MAJOR",
#         "conductorName": "Conlon, James",
#         "soloists": [
#           {
#             "soloistName": "Ohlsson, Garrick",
#             "soloistInstrument": "Piano",
#             "soloistRoles": "S"
#           }
#         ]
#       },
#       {
#         "ID": "0*",
#         "interval": "Intermission",
#         "soloists": []
#       },
#       {
#         "ID": "53334*",
#         "composerName": "Dvorak,  Anton\u00edn",
#         "workTitle": "SYMPHONY NO. 4, D MINOR, OP.13",
#         "conductorName": "Conlon, James",
#         "soloists": []
#       }
#     ]
#   }
# ]

# %%
repeated_programs = [program for program in programs['programs'] if len(program['concerts']) > 1]

# %%
repeated_programs
# Out:
# [{'id': '53baad78-6929-4419-8f4f-6ac4204fcb2a-0.1',
#   'programID': '7211',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-10-20T04:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-10-21T04:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '3965*',
#     'composerName': 'Anthem,',
#     'workTitle': 'UNITED STATES',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '1245*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'ABDUCTION FROM THE SERAGLIO, THE: OVERTURE (ARR. Busoni)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '51071*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'CONCERTO, PIANO NO. 25, C MAJOR, K.503',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Serkin, Rudolf',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '51041*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'CONCERTO, PIANO NO. 16, D MAJOR, K.451',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Serkin, Rudolf',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '51061*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'CONCERTO, PIANO NO. 23, A MAJOR, K.488',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Serkin, Rudolf',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]}]},
#  {'id': 'f8221d11-8af5-4658-b67d-6e175390209f-0.1',
#   'programID': '7222',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-10-27T04:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-10-28T04:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '548*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'SINFONIA CONCERTANTE, VLN/VLA/VC, A MAJOR, K.320E [ANH. 104]',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Corigliano, John, Sr.',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'A'},
#      {'soloistName': 'Lincer, William',
#       'soloistInstrument': 'Viola',
#       'soloistRoles': 'A'},
#      {'soloistName': 'Varga, Laszlo',
#       'soloistInstrument': 'Cello',
#       'soloistRoles': 'A'}]},
#    {'ID': '9006*2',
#     'composerName': 'Wagner,  Richard',
#     'workTitle': 'GOTTERDAMMERUNG [GÖTTERDÄMMERUNG]',
#     'movement': 'ACT III: COMPLETE',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': 'adc236dd-1014-46ed-9c42-e90a46e64d9d-0.1',
#   'programID': '4207',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-11-03T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-11-04T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '8837*10',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'FIDELIO, OP. 72',
#     'movement': 'Overture',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '51059*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'CONCERTO, PIANO NO. 22, E-FLAT MAJOR, K.482',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Scarpini, Pietro',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '552*',
#     'composerName': 'Weber,  Ben',
#     'workTitle': 'PRELUDE AND PASSACAGLIA, OP. 42',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '51929*',
#     'composerName': 'Strauss,  Richard',
#     'workTitle': 'ALSO SPRACH ZARATHUSTRA, OP. 30',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': '10f0ddd7-8ff3-4517-b312-05c07a33f61f-0.1',
#   'programID': '4221',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-11-10T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-11-11T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '50746*',
#     'composerName': 'Weber,  Carl  Maria Von',
#     'workTitle': 'SYMPHONY NO. 1, C MAJOR, J. 50',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '52915*',
#     'composerName': 'Schuman,  William',
#     'workTitle': 'JUDITH',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '50731*',
#     'composerName': 'Weber,  Carl  Maria Von',
#     'workTitle': 'KONZERTSTUCK IN F MINOR FOR PIANO, OP.79',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Casadesus, Robert',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '557*',
#     'composerName': 'Casadesus,  Robert',
#     'workTitle': 'CONCERTO, PIANO, E MINOR, OP.37',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Casadesus, Robert',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]}]},
#  {'id': '671d1ec9-5ef5-4b6b-ad0d-bf255acbe64b-0.1',
#   'programID': '4234',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-11-17T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-11-18T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '9187*1',
#     'composerName': 'Weber,  Carl  Maria Von',
#     'workTitle': 'EURYANTHE, OP. 81, J. 291',
#     'movement': 'Overture',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []},
#    {'ID': '51880*',
#     'composerName': 'Brahms,  Johannes',
#     'workTitle': 'SYMPHONY NO. 3 IN F MAJOR, OP. 90',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '2229*',
#     'composerName': 'Bruch,  Max',
#     'workTitle': 'CONCERTO, VIOLIN, NO. 1, G MINOR, OP.26',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': [{'soloistName': 'Elman, Mischa',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '3417*',
#     'composerName': 'Debussy,  Claude',
#     'workTitle': 'MER, LA [THE SEA]',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []}]},
#  {'id': '934f8913-5902-46a1-88dd-7d8382fe2011-0.1',
#   'programID': '4248',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-11-24T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-11-25T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '1914*2',
#     'composerName': 'Berlioz,  Hector',
#     'workTitle': 'BENVENUTO CELLINI',
#     'movement': 'Overture',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []},
#    {'ID': '51356*2',
#     'composerName': 'Berlioz,  Hector',
#     'workTitle': 'ROMEO ET JULIETTE, OP.17',
#     'movement': 'Introduction: Combat - Tumult - Intervention of the Prince',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []},
#    {'ID': '51356*6',
#     'composerName': 'Berlioz,  Hector',
#     'workTitle': 'ROMEO ET JULIETTE, OP.17',
#     'movement': "Star-lit night - Capulet's garden, silent and deserted - The young Capulets, leaving the hall, pass by singing fragements of the dance music (Love scene, Adagio)",
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []},
#    {'ID': '51356*7',
#     'composerName': 'Berlioz,  Hector',
#     'workTitle': 'ROMEO ET JULIETTE, OP.17',
#     'movement': 'Queen Mab, or the Fairy of dreams (Scherzo)',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []},
#    {'ID': '51356*17',
#     'composerName': 'Berlioz,  Hector',
#     'workTitle': 'ROMEO ET JULIETTE, OP.17',
#     'movement': 'Romeo Alone',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []},
#    {'ID': '51356*14',
#     'composerName': 'Berlioz,  Hector',
#     'workTitle': 'ROMEO ET JULIETTE, OP.17',
#     'movement': "Great festivities in Capulet's palace",
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '3181*',
#     'composerName': 'Chopin,  Frédéric',
#     'workTitle': 'CONCERTO, PIANO, NO. 2, F MINOR, OP. 21',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': [{'soloistName': 'Brailowsky, Alexander',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]}]},
#  {'id': 'c08edcd2-16e6-492f-bf06-ded0134613c7-0.1',
#   'programID': '1144',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-12-01T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-12-02T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '52361*',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'CORIOLAN OVERTURE, OP. 62',
#     'conductorName': 'Szell, George',
#     'soloists': []},
#    {'ID': '3163*',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'CONCERTO, PIANO, NO. 4, G MAJOR, OP. 58',
#     'conductorName': 'Szell, George',
#     'soloists': [{'soloistName': 'Istomin, Eugene',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '52449*',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'SYMPHONY NO. 6 IN F MAJOR, OP.68 (PASTORAL)',
#     'conductorName': 'Szell, George',
#     'soloists': []}]},
#  {'id': 'bafba5a7-6e5f-4e04-989a-1aabd13df00a-0.1',
#   'programID': '1157',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-12-08T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-12-09T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '1862*1',
#     'composerName': 'Rossini,  Gioachino',
#     'workTitle': 'SCALA DI SETA, LA (THE SILKEN LADDER)',
#     'movement': 'Overture',
#     'conductorName': 'Szell, George',
#     'soloists': []},
#    {'ID': '564*',
#     'composerName': 'Wagenaar,  Bernard',
#     'workTitle': 'FIVE TABLEAUX FOR VIOLONCELLO',
#     'conductorName': 'Szell, George',
#     'soloists': [{'soloistName': 'Kurtz, Edmund',
#       'soloistInstrument': 'Cello',
#       'soloistRoles': 'S'}]},
#    {'ID': '1518*',
#     'composerName': 'Saint-Saens [Saint-Saëns],  Camille',
#     'workTitle': 'CONCERTO, CELLO, NO. 1, A MINOR, OP. 33',
#     'conductorName': 'Szell, George',
#     'soloists': [{'soloistName': 'Kurtz, Edmund',
#       'soloistInstrument': 'Cello',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '53254*',
#     'composerName': 'Sibelius,  Jean',
#     'workTitle': 'SYMPHONY NO. 2, D MAJOR, OP. 43',
#     'conductorName': 'Szell, George',
#     'soloists': []}]},
#  {'id': 'eb74fbb3-12d5-4ec6-bb08-c8665518376d-0.1',
#   'programID': '1168',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-12-15T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-12-16T05:00:00Z',
#     'Time': '2:30PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-12-18T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '53341*',
#     'composerName': 'Dvorak,  Antonín',
#     'workTitle': 'SYMPHONY NO. 7, D MINOR, OP.70 (OLD NO. 2)',
#     'conductorName': 'Szell, George',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '563*',
#     'composerName': 'Sibelius,  Jean',
#     'workTitle': 'CONCERTO, VIOLIN, D MINOR, OP .47',
#     'conductorName': 'Szell, George',
#     'soloists': [{'soloistName': 'Gitlis, Ivry',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '715*',
#     'composerName': 'Ravel,  Maurice',
#     'workTitle': 'VALSE, LA',
#     'conductorName': 'Szell, George',
#     'soloists': []}]},
#  {'id': '96d8124c-e016-49ac-8991-93ef6a213fca-0.1',
#   'programID': '1176',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-12-22T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-12-23T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '8864*13',
#     'composerName': 'Musorgsky,  Modest',
#     'workTitle': 'KHOVANSHCHINA (ARR. Rimsky-Korsakov)',
#     'movement': 'Prelude',
#     'conductorName': 'Szell, George',
#     'soloists': []},
#    {'ID': '50064*',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SYMPHONY NO. 4, F MINOR, OP. 36',
#     'conductorName': 'Szell, George',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '4073*',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'CONCERTO, VIOLIN, D MAJOR, OP.35',
#     'conductorName': 'Szell, George',
#     'soloists': [{'soloistName': 'Morini, Erica',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]}]},
#  {'id': 'b00e4499-a291-4fec-93aa-74199346079a-0.1',
#   'programID': '1189',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-12-29T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-12-30T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '1252*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'DON GIOVANNI: OVERTURE, K.527 (ARR. Busoni)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '53147*',
#     'composerName': 'Shostakovich,  Dmitri',
#     'workTitle': 'CONCERTO, VIOLIN, NO. 1, OP. 99 (OP. 77)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Oistrakh, David',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '50322*',
#     'composerName': 'Vaughan Williams,  Ralph',
#     'workTitle': 'SYMPHONY NO. 4 IN F MINOR',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': '031d6dbf-ba95-406e-a7a2-5765d03e144e-0.1',
#   'programID': '4877',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-01-05T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-01-06T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '53757*',
#     'composerName': 'Prokofiev,  Sergei',
#     'workTitle': 'LIEUTENANT KIJE, OP. 60: SUITE',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '1323*',
#     'composerName': 'Dvorak,  Antonín',
#     'workTitle': 'CONCERTO, VIOLIN, A MINOR, OP.53',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Milstein, Nathan',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '53071*',
#     'composerName': 'Schumann,  Robert',
#     'workTitle': 'SYMPHONY NO. 2, C MAJOR, OP. 61',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': '0ed027a6-473f-4eb5-9e06-30a4318dfbae-0.1',
#   'programID': '4887',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-01-12T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-01-13T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '52626*',
#     'composerName': 'Barber,  Samuel',
#     'workTitle': 'SCHOOL FOR SCANDAL OVERTURE',
#     'conductorName': 'Rudolf, Max',
#     'soloists': []},
#    {'ID': '51091*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'CONCERTO, VIOLIN NO. 3, G MAJOR, K.216',
#     'conductorName': 'Rudolf, Max',
#     'soloists': [{'soloistName': 'Stern, Isaac',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '52434*',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'SYMPHONY NO. 2 IN D MAJOR, OP.36',
#     'conductorName': 'Rudolf, Max',
#     'soloists': []},
#    {'ID': '51965*',
#     'composerName': 'Strauss,  Richard',
#     'workTitle': 'TILL EULENSPIEGELS LUSTIGE STREICHE, OP. 28',
#     'conductorName': 'Rudolf, Max',
#     'soloists': []}]},
#  {'id': 'fefd93c8-1d47-4583-b6a2-93d80400ef70-0.1',
#   'programID': '4898',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-01-19T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-01-20T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '52521*',
#     'composerName': 'Creston,  Paul',
#     'workTitle': 'SYMPHONY NO. 2, OP.35',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []},
#    {'ID': '51099*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'CONCERTO, VIOLIN NO. 5, A MAJOR, K.219',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': [{'soloistName': 'Corigliano, John, Sr.',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '51954*',
#     'composerName': 'Strauss,  Richard',
#     'workTitle': 'HELDENLEBEN, EIN, OP. 40',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': [{'soloistName': 'Corigliano, John, Sr.',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'A'}]}]},
#  {'id': 'cb51facc-efdc-4a8b-a1cb-d52f84a6c803-0.1',
#   'programID': '4903',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-01-21T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-01-22T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '51701*1',
#     'composerName': 'Rossini,  Gioachino',
#     'workTitle': "ITALIANA IN ALGERI, L'",
#     'movement': 'Overture',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []},
#    {'ID': '52521*',
#     'composerName': 'Creston,  Paul',
#     'workTitle': 'SYMPHONY NO. 2, OP.35',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '3685*',
#     'composerName': 'Brahms,  Johannes',
#     'workTitle': 'CONCERTO, VIOLIN, D MAJOR, OP.77',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': [{'soloistName': 'Milstein, Nathan',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]}]},
#  {'id': 'b4167661-4619-4502-8b60-e633cfa1cc91-0.1',
#   'programID': '4906',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-01-26T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-01-27T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '588*',
#     'composerName': 'Buxtehude,  Dietrich',
#     'workTitle': 'CHACONNE, E MINOR (ARR. Chavez [Chávez])',
#     'conductorName': 'Chavez [Chávez], Carlos',
#     'soloists': []},
#    {'ID': '52337*',
#     'composerName': 'Chavez [Chávez],  Carlos',
#     'workTitle': 'SYMPHONY NO. 3',
#     'conductorName': 'Chavez [Chávez], Carlos',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '2190*',
#     'composerName': 'Prokofiev,  Sergei',
#     'workTitle': 'CONCERTO, PIANO, NO. 3, OP. 26, C MAJOR',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Bachauer, Gina',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '3800*',
#     'composerName': 'Bizet,  Georges',
#     'workTitle': "PETITE SUITE: JEUX D'ENFANTS, OP.22",
#     'conductorName': 'Mitropoulos, Dimitri;  Chavez [Chávez], Carlos',
#     'soloists': []},
#    {'ID': '50858*',
#     'composerName': 'Kodaly [Kodály],  Zoltán',
#     'workTitle': 'HARY JANOS: SUITE',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Koves-Steiner, Toni',
#       'soloistInstrument': 'Cimbalom',
#       'soloistRoles': 'A'}]}]},
#  {'id': 'a1725fec-c694-4435-9d3e-bfae34691314-0.1',
#   'programID': '1829',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-02-02T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-02-03T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '52313*',
#     'composerName': 'Chausson,  Ernest',
#     'workTitle': 'SYMPHONY IN B FLAT MAJOR, OP. 20',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '52621*',
#     'composerName': 'Barber,  Samuel',
#     'workTitle': "MEDEA'S MEDITATION AND DANCE OF VENGEANCE, OP. 23A",
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '3685*',
#     'composerName': 'Brahms,  Johannes',
#     'workTitle': 'CONCERTO, VIOLIN, D MAJOR, OP.77',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Rabin, Michael',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]}]},
#  {'id': '05fab3f3-140c-4348-b497-f0e589c8e6ef-0.1',
#   'programID': '1849',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-02-09T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-02-10T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '52132*',
#     'composerName': 'Haydn,  Franz  Joseph',
#     'workTitle': 'SYMPHONY NO. 103, E FLAT MAJOR (DRUMROLL)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '3800*',
#     'composerName': 'Bizet,  Georges',
#     'workTitle': "PETITE SUITE: JEUX D'ENFANTS, OP.22",
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '2068*',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'CONCERTO, VIOLIN, D MAJOR, OP.61',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Heifetz, Jascha',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]}]},
#  {'id': '80b38173-74fe-484b-96da-cd5d65a44891-0.1',
#   'programID': '1870',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-02-16T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-02-17T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '51877*',
#     'composerName': 'Shostakovich,  Dmitri',
#     'workTitle': 'FESTIVE OVERTURE, OP. 96',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '2214*',
#     'composerName': 'Rachmaninoff,  Sergei',
#     'workTitle': 'CONCERTO, PIANO, NO. 3, D MINOR, OP. 30',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Malcuzynski, Witold',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '51583*',
#     'composerName': 'Bloch,  Ernest',
#     'workTitle': 'SCHELOMO',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Varga, Laszlo',
#       'soloistInstrument': 'Cello',
#       'soloistRoles': 'S'}]},
#    {'ID': '51149*',
#     'composerName': 'Liszt,  Franz',
#     'workTitle': 'PRELUDES, LES (SYMPHONIC POEM NO. 3)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': 'ccdd3a63-957c-4f0f-8372-ab10bf8b2d10-0.1',
#   'programID': '1890',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-02-23T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-02-24T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '611*',
#     'composerName': 'Bach,  Johann  Sebastian',
#     'workTitle': 'FANTASIA AND FUGUE, G MINOR, BWV 542 (ARR. Mitropoulos)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '617*',
#     'composerName': 'Kirchner,  Leon',
#     'workTitle': 'CONCERTO, PIANO, NO. 1',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Kirchner, Leon',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '3846*',
#     'composerName': 'Strauss,  Richard',
#     'workTitle': 'ALPINE SYMPHONY, OP. 64',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': '5fb526e9-fa6e-4c95-86e0-aaad285a4672-0.1',
#   'programID': '2364',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Festival',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-03-01T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Festival',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-03-02T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '51614*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'SYMPHONY NO. 29, A MAJOR, K.186A (OLD K.201)',
#     'conductorName': 'Walter, Bruno',
#     'soloists': []},
#    {'ID': '50606*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'CONCERTO, PIANO NO. 17, G MAJOR, K.453',
#     'conductorName': 'Walter, Bruno',
#     'soloists': [{'soloistName': 'Hess, Myra',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '51668*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'SYMPHONY NO. 41, C MAJOR, K.551, "JUPITER"',
#     'conductorName': 'Walter, Bruno',
#     'soloists': []}]},
#  {'id': 'e700354b-92c4-449c-ad88-9eb7ead7dab0-0.1',
#   'programID': '2373',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Festival',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-03-08T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Festival',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-03-09T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '711*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'SYMPHONY NO. 25, G MINOR, K.173DB (OLD K.183)',
#     'conductorName': 'Walter, Bruno',
#     'soloists': []},
#    {'ID': '51322*14',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'MASS, C MINOR, K.417A (OLD K.427), "GREAT"',
#     'movement': 'Et incarnatus est',
#     'conductorName': 'Walter, Bruno',
#     'soloists': [{'soloistName': 'Seefried, Irmgard',
#       'soloistInstrument': 'Soprano',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '50610*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'REQUIEM, K.626 (ARR. Sussmayr)',
#     'conductorName': 'Walter, Bruno',
#     'soloists': [{'soloistName': 'Seefried, Irmgard',
#       'soloistInstrument': 'Soprano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Tourel, Jennie',
#       'soloistInstrument': 'Mezzo-Soprano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Simoneau, Leopold',
#       'soloistInstrument': 'Tenor',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Warfield, William',
#       'soloistInstrument': 'Baritone',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Westminster Choir',
#       'soloistInstrument': 'Chorus',
#       'soloistRoles': 'S'}]}]},
#  {'id': 'ae9adace-da71-4e12-a79e-7dba514529c9-0.1',
#   'programID': '6239',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-03-15T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-03-16T05:00:00Z',
#     'Time': '2:30PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-03-18T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '52513*',
#     'composerName': 'Creston,  Paul',
#     'workTitle': 'DANCE OVERTURE, OP.62',
#     'conductorName': 'Cantelli, Guido',
#     'soloists': []},
#    {'ID': '53078*',
#     'composerName': 'Schumann,  Robert',
#     'workTitle': 'SYMPHONY NO. 4, D MINOR, OP. 120',
#     'conductorName': 'Cantelli, Guido',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '3163*',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'CONCERTO, PIANO, NO. 4, G MAJOR, OP. 58',
#     'conductorName': 'Cantelli, Guido',
#     'soloists': [{'soloistName': 'Backhaus, Wilhelm',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]}]},
#  {'id': 'cc870599-10f8-4fdd-a372-72858885ea2b-0.1',
#   'programID': '6247',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-03-22T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-03-23T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '51985*',
#     'composerName': 'Britten,  Benjamin',
#     'workTitle': 'SINFONIA DA REQUIEM, OP. 20',
#     'conductorName': 'Cantelli, Guido',
#     'soloists': []},
#    {'ID': '51944*',
#     'composerName': 'Strauss,  Richard',
#     'workTitle': 'DON JUAN, OP. 20',
#     'conductorName': 'Cantelli, Guido',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '3548*',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'CONCERTO, PIANO, NO. 5, E FLAT MAJOR, OP.73',
#     'conductorName': 'Cantelli, Guido',
#     'soloists': [{'soloistName': 'Gieseking, Walter',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]}]},
#  {'id': '1e69e211-9f09-45cb-b114-fa6e3ea0fb80-0.1',
#   'programID': '6253',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-03-29T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-03-30T05:00:00Z',
#     'Time': '2:30PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-03-31T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-04-01T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '9008*12',
#     'composerName': 'Wagner,  Richard',
#     'workTitle': 'PARSIFAL, WWV 111',
#     'movement': 'Good Friday Music, Act III',
#     'conductorName': 'Cantelli, Guido',
#     'soloists': []},
#    {'ID': '52074*4',
#     'composerName': 'Verdi,  Giuseppe',
#     'workTitle': 'FOUR SACRED PIECES',
#     'movement': 'Te Deum',
#     'conductorName': 'Cantelli, Guido',
#     'soloists': [{'soloistName': 'Westminster Choir',
#       'soloistInstrument': 'Chorus',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '50235*',
#     'composerName': 'Brahms,  Johannes',
#     'workTitle': 'ALTO RHAPSODY, OP. 53',
#     'conductorName': 'Cantelli, Guido',
#     'soloists': [{'soloistName': 'Lipton, Martha',
#       'soloistInstrument': 'Mezzo-Soprano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Westminster Choir',
#       'soloistInstrument': 'Mens Chorus',
#       'soloistRoles': 'S'}]},
#    {'ID': '636*',
#     'composerName': 'Monteverdi,  Claudio',
#     'workTitle': 'MAGNIFICAT (ARR. Ghedini)',
#     'conductorName': 'Cantelli, Guido',
#     'soloists': [{'soloistName': 'Westminster Choir',
#       'soloistInstrument': 'Chorus',
#       'soloistRoles': 'S'}]}]},
#  {'id': '264452f8-02d7-478a-b1fb-368cc99bf38e-0.1',
#   'programID': '3200',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-04-05T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-04-06T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '52076*',
#     'composerName': 'Haydn,  Franz  Joseph',
#     'workTitle': 'SYMPHONY NO.  88, G MAJOR',
#     'conductorName': 'Cantelli, Guido',
#     'soloists': []},
#    {'ID': '50097*',
#     'composerName': 'Hindemith,  Paul',
#     'workTitle': 'CONCERT MUSIC, STRINGS AND BRASS, OP. 50',
#     'conductorName': 'Cantelli, Guido',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '1389*',
#     'composerName': 'Brahms,  Johannes',
#     'workTitle': 'CONCERTO, PIANO, NO. 1, D MINOR, OP.15',
#     'conductorName': 'Cantelli, Guido',
#     'soloists': [{'soloistName': 'Firkusny, Rudolf',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]}]},
#  {'id': '914a94c6-1302-46c1-bd10-c75aea0a23e3-0.1',
#   'programID': '3216',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-04-12T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-04-13T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '655*',
#     'composerName': 'Bach,  Johann  Sebastian',
#     'workTitle': 'PRELUDE AND FUGUE, D MAJOR, BWV 532 (ARR. Respighi)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '3985*',
#     'composerName': 'Mahler,  Gustav',
#     'workTitle': 'SYMPHONY NO.  3 IN D MINOR',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []}]},
#  {'id': '970de8de-7c21-4313-8cec-090fc5f28a32-0.1',
#   'programID': '3224',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-04-19T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-04-20T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '52612*',
#     'composerName': 'Debussy,  Claude',
#     'workTitle': "L'ISLE JOYEUSE (ARR. Molinari)",
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '665*',
#     'composerName': 'Thomson,  Virgil',
#     'workTitle': 'CONCERTO, FLUTE, STRINGS AND PERCUSSION',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Wummer, John',
#       'soloistInstrument': 'Flute',
#       'soloistRoles': 'A'}]},
#    {'ID': '2907*',
#     'composerName': 'Prokofiev,  Sergei',
#     'workTitle': 'SINFONIA CONCERTANTE, OP.125 (CON., CELLO, NO. 2)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Rostropovich, Mstislav',
#       'soloistInstrument': 'Cello',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '51872*',
#     'composerName': 'Brahms,  Johannes',
#     'workTitle': 'SYMPHONY NO. 2 IN D MAJOR, OP. 73',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': '4569da4d-147d-4201-837d-86cd7eb395ce-0.1',
#   'programID': '3231',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-04-26T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-04-27T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '51547*',
#     'composerName': 'Ravel,  Maurice',
#     'workTitle': 'ALBORADA DEL GRACIOSO',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '2349*',
#     'composerName': 'Saint-Saens [Saint-Saëns],  Camille',
#     'workTitle': 'CONCERTO, VIOLIN, NO. 3, OP. 61, B MINOR',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Francescatti, Zino',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '53988*',
#     'composerName': 'Rachmaninoff,  Sergei',
#     'workTitle': 'SYMPHONY NO. 2, E MINOR, OP. 27',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': 'f4584d5e-9b8d-4764-b34c-d65599fdbb4b-0.1',
#   'programID': '729',
#   'orchestra': 'New York Philharmonic',
#   'season': '1956-57',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-10-18T04:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-10-19T04:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '3965*',
#     'composerName': 'Anthem,',
#     'workTitle': 'UNITED STATES',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '53881*',
#     'composerName': 'Handel,  George  Frideric',
#     'workTitle': 'CONCERTO GROSSO, OP. 3, NO. 2, B FLAT MAJOR (ARR. Seiffert)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '52614*',
#     'composerName': 'Barber,  Samuel',
#     'workTitle': 'CAPRICORN CONCERTO',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Wummer, John',
#       'soloistInstrument': 'Flute',
#       'soloistRoles': 'A'},
#      {'soloistName': 'Gomberg, Harold',
#       'soloistInstrument': 'Oboe',
#       'soloistRoles': 'A'},
#      {'soloistName': 'Vacchiano, William',
#       'soloistInstrument': 'Trumpet',
#       'soloistRoles': 'A'}]},
#    {'ID': '51944*',
#     'composerName': 'Strauss,  Richard',
#     'workTitle': 'DON JUAN, OP. 20',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '52446*',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'SYMPHONY NO. 5 IN C MINOR, OP.67',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': '109ccf6e-8f12-4bea-bb44-708d5db57ced-0.1',
#   'programID': '743',
#   'orchestra': 'New York Philharmonic',
#   'season': '1956-57',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-10-25T04:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-10-26T04:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '2414*1',
#     'composerName': 'Gluck,  Christoph  Willibald',
#     'workTitle': 'ALCESTE',
#     'movement': 'Overture',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '51884*',
#     'composerName': 'Brahms,  Johannes',
#     'workTitle': 'SYMPHONY NO. 4 IN E MINOR, OP. 98',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '5122*',
#     'composerName': 'Read,  Gardner',
#     'workTitle': 'TOCCATA GIOCOSA, OP. 94',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '53102*',
#     'composerName': 'Scriabin,  Alexander',
#     'workTitle': 'SYMPHONY NO. 4, "LE POEME D\'EXTASE," OP. 54',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': '3be33e99-ced2-4b37-8424-50055ca3a172-0.1',
#   'programID': '5095',
#   'orchestra': 'New York Philharmonic',
#   'season': '1956-57',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-11-01T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-11-02T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '52122*',
#     'composerName': 'Haydn,  Franz  Joseph',
#     'workTitle': 'SYMPHONY NO. 100, G MAJOR (MILITARY)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '3134*',
#     'composerName': 'Schuller,  Gunther',
#     'workTitle': 'SYMPHONY, BRASS AND PERCUSSION, OP. 16',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '50332*',
#     'composerName': 'Falla,  Manuel  de',
#     'workTitle': 'NIGHTS IN THE GARDENS OF SPAIN',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Casadesus, Robert',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '3433*',
#     'composerName': 'Ravel,  Maurice',
#     'workTitle': 'CONCERTO, PIANO, D MAJOR (LEFT HAND)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Casadesus, Robert',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]}]},
#  {'id': 'ad4c691e-66ac-4f05-9f66-076bbb004a6b-0.1',
#   'programID': '5116',
#   'orchestra': 'New York Philharmonic',
#   'season': '1956-57',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-11-08T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-11-09T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '5148*',
#     'composerName': 'Bach,  Johann  Sebastian',
#     'workTitle': 'CHORALE, "O MENSCH, BEWEIN\' DEIN\' SUNDE GROSS", BWV 622 (ARR. Reger)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '8863*1',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'CLEMENZA DI TITO, LA, K.621',
#     'movement': 'Overture',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '52909*',
#     'composerName': 'Schuman,  William',
#     'workTitle': 'CREDENDUM (ARTICLE OF FAITH)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '3281*',
#     'composerName': 'Rachmaninoff,  Sergei',
#     'workTitle': 'CONCERTO, PIANO, NO. 1, F SHARP MINOR, OP.1',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Janis, Byron',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '53068*',
#     'composerName': 'Schumann,  Robert',
#     'workTitle': 'SYMPHONY NO. 1 IN B FLAT MAJOR, OP.38 (SPRING)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': '980cab47-892b-4ef0-a3cb-51ba93e61333-0.1',
#   'programID': '5127',
#   'orchestra': 'New York Philharmonic',
#   'season': '1956-57',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-11-15T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-11-16T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '52108*',
#     'composerName': 'Haydn,  Franz  Joseph',
#     'workTitle': 'SYMPHONY NO.  96, D MAJOR (THE MIRACLE)',
#     'conductorName': 'Paray, Paul',
#     'soloists': []},
#    {'ID': '51049*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'CONCERTO, PIANO NO. 20, D MINOR, K.466',
#     'conductorName': 'Paray, Paul',
#     'soloists': [{'soloistName': 'Haskil, Clara',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '5154*',
#     'composerName': 'Barraud,  Henri',
#     'workTitle': 'OFFRANDE A UNE OMBRE',
#     'conductorName': 'Paray, Paul',
#     'soloists': []},
#    {'ID': '3417*',
#     'composerName': 'Debussy,  Claude',
#     'workTitle': 'MER, LA [THE SEA]',
#     'conductorName': 'Paray, Paul',
#     'soloists': []}]},
#  {'id': '1c351c5d-6193-450b-81b9-6746cbbdd3d7-0.1',
#   'programID': '5133',
#   'orchestra': 'New York Philharmonic',
#   'season': '1956-57',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-11-17T05:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-11-18T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '52108*',
#     'composerName': 'Haydn,  Franz  Joseph',
#     'workTitle': 'SYMPHONY NO.  96, D MAJOR (THE MIRACLE)',
#     'conductorName': 'Paray, Paul',
#     'soloists': []},
#    {'ID': '52502*',
# ...
#     'workTitle': 'PORGY AND BESS',
#     'movement': "My Man's Gone Now, Serena/Chorus, Act I, scene 2",
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Tyler, Veronica',
#       'soloistInstrument': 'Soprano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Schola Cantorum of NY',
#       'soloistInstrument': 'Chorus',
#       'soloistRoles': 'S'}]},
#    {'ID': '9210*11',
#     'composerName': 'Gershwin,  George',
#     'workTitle': 'PORGY AND BESS',
#     'movement': "Leavin' for the Promise' Lan', Bess/Chorus, Act II (Train song)",
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Tyler, Veronica',
#       'soloistInstrument': 'Soprano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Schola Cantorum of NY',
#       'soloistInstrument': 'Chorus',
#       'soloistRoles': 'S'}]},
#    {'ID': '9210*8',
#     'composerName': 'Gershwin,  George',
#     'workTitle': 'PORGY AND BESS',
#     'movement': "I Got Plenty o' Nuttin', Porgy/Chorus, Act II, scene 1",
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Boatwright, McHenry',
#       'soloistInstrument': 'Baritone',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Schola Cantorum of NY',
#       'soloistInstrument': 'Chorus',
#       'soloistRoles': 'S'}]},
#    {'ID': '9210*9',
#     'composerName': 'Gershwin,  George',
#     'workTitle': 'PORGY AND BESS',
#     'movement': 'Bess, You is My Woman Now, Porgy/Bess, Act II, scene 1',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Boatwright, McHenry',
#       'soloistInstrument': 'Baritone',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Tyler, Veronica',
#       'soloistInstrument': 'Soprano',
#       'soloistRoles': 'S'}]},
#    {'ID': '9210*10',
#     'composerName': 'Gershwin,  George',
#     'workTitle': 'PORGY AND BESS',
#     'movement': "Oh, I Can't Sit Down, (Chorus), Act II, scene 1",
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Schola Cantorum of NY',
#       'soloistInstrument': 'Chorus',
#       'soloistRoles': 'S'}]},
#    {'ID': '9210*13',
#     'composerName': 'Gershwin,  George',
#     'workTitle': 'PORGY AND BESS',
#     'movement': "It Ain't Necessarily So, Sportin' Life/Chorus, Act II, scene 2",
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Boatwright, McHenry',
#       'soloistInstrument': 'Baritone',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Schola Cantorum of NY',
#       'soloistInstrument': 'Chorus',
#       'soloistRoles': 'S'}]},
#    {'ID': '9210*21',
#     'composerName': 'Gershwin,  George',
#     'workTitle': 'PORGY AND BESS',
#     'movement': "There's a Boat Dat's Leavin' Soon for New York, Sportin' Life, Act III, scene 2",
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Boatwright, McHenry',
#       'soloistInstrument': 'Baritone',
#       'soloistRoles': 'S'}]},
#    {'ID': '9210*23',
#     'composerName': 'Gershwin,  George',
#     'workTitle': 'PORGY AND BESS',
#     'movement': "Oh Lawd, I'm on My Way, Porgy/Chorus, Act III, scene 3",
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Boatwright, McHenry',
#       'soloistInstrument': 'Baritone',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Schola Cantorum of NY',
#       'soloistInstrument': 'Chorus',
#       'soloistRoles': 'S'}]}]},
#  {'id': '27109cd6-3a92-4c74-807a-9e7d3017dee5-0.1',
#   'programID': '6309',
#   'orchestra': 'New York Philharmonic',
#   'season': '1962-63',
#   'concerts': [{'eventType': 'Promenade',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Philharmonic Hall',
#     'Date': '1963-06-07T04:00:00Z',
#     'Time': '8:30PM'},
#    {'eventType': 'Promenade',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Philharmonic Hall',
#     'Date': '1963-06-08T04:00:00Z',
#     'Time': '8:30PM'}],
#   'works': [{'ID': '8963*2',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'EUGENE ONEGIN, OP. 24',
#     'movement': "Act II, Scene 1: Entr' acte",
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '8963*6',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'EUGENE ONEGIN, OP. 24',
#     'movement': 'Waltz',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '8963*3',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'EUGENE ONEGIN, OP. 24',
#     'movement': 'Act I, Scene 2 (Tatyana): Letter Scene',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Saunders, Arlene',
#       'soloistInstrument': 'Soprano',
#       'soloistRoles': 'None'}]},
#    {'ID': '8958*3',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SWAN LAKE: BALLET',
#     'movement': 'Wedding Dance, Act III, No. 16',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Wilde, Patricia',
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Ludlow, Conrad',
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'}]},
#    {'ID': '8958*4',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SWAN LAKE: BALLET',
#     'movement': "Pas d'action (White Swan) [Act II, No. 13, Var. V, abridged ]",
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Wilde, Patricia',
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Ludlow, Conrad',
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'}]},
#    {'ID': '8958*10',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SWAN LAKE: BALLET',
#     'movement': 'Introduction/Opening Scene, Act II, No. 10',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '8958*9',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SWAN LAKE: BALLET',
#     'movement': "Siegfried's Solo, Act II",
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Ludlow, Conrad',
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'}]},
#    {'ID': '8958*14',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SWAN LAKE: BALLET',
#     'movement': "Odette's Solo, Act II, No. 13/II",
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Wilde, Patricia',
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'}]},
#    {'ID': '8958*15',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SWAN LAKE: BALLET',
#     'movement': 'Coda (Siegfried + Odette), Act II, 13/VII',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Wilde, Patricia',
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Ludlow, Conrad',
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '242*',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'NUTCRACKER, THE: SUITE, WITH VERSES BY NASH',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Nash, Ogden',
#       'soloistInstrument': 'Narrator',
#       'soloistRoles': 'S'}]},
#    {'ID': '50005*',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'MARCHE SLAV, OP.31',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []}]},
#  {'id': 'cfad058f-03e4-41bc-a009-ff00fd477b6e-0.1',
#   'programID': '6314',
#   'orchestra': 'New York Philharmonic',
#   'season': '1962-63',
#   'concerts': [{'eventType': 'Promenade',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Philharmonic Hall',
#     'Date': '1963-06-12T04:00:00Z',
#     'Time': '8:30PM'},
#    {'eventType': 'Promenade',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Philharmonic Hall',
#     'Date': '1963-06-13T04:00:00Z',
#     'Time': '8:30PM'},
#    {'eventType': 'Promenade',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Philharmonic Hall',
#     'Date': '1963-06-14T04:00:00Z',
#     'Time': '8:30PM'}],
#   'works': [{'ID': '53726*',
#     'composerName': 'Previn,  André',
#     'workTitle': 'OVERTURE TO A COMEDY',
#     'conductorName': 'Previn, André',
#     'soloists': []},
#    {'ID': '53732*',
#     'composerName': 'Prokofiev,  Sergei',
#     'workTitle': 'SYMPHONY NO. 1, OP. 25 (CLASSICAL)',
#     'conductorName': 'Previn, André',
#     'soloists': []},
#    {'ID': '52492*',
#     'composerName': 'Mendelssohn,  Felix',
#     'workTitle': 'CONCERTO, PIANO, NO. 1, G MINOR, OP.25',
#     'conductorName': 'Previn, André',
#     'soloists': [{'soloistName': 'Previn, André',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '52340*',
#     'composerName': 'Copland,  Aaron',
#     'workTitle': 'RED PONY, SUITE',
#     'conductorName': 'Previn, André',
#     'soloists': []},
#    {'ID': '248*',
#     'composerName': 'Bernstein,  Leonard',
#     'workTitle': 'WEST SIDE STORY, JAZZ IMPROVISATIONS',
#     'conductorName': 'Previn, André',
#     'soloists': [{'soloistName': 'Previn, André',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Manne, Shelly',
#       'soloistInstrument': 'Percussion',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Mitchell, Red',
#       'soloistInstrument': 'Double Bass',
#       'soloistRoles': 'S'}]}]},
#  {'id': '7bfac6e0-cead-42b2-b2a0-4a83257af860-0.1',
#   'programID': '6318',
#   'orchestra': 'New York Philharmonic',
#   'season': '1962-63',
#   'concerts': [{'eventType': 'Promenade',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Philharmonic Hall',
#     'Date': '1963-06-15T04:00:00Z',
#     'Time': '8:30PM'},
#    {'eventType': 'Promenade',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Philharmonic Hall',
#     'Date': '1963-06-16T04:00:00Z',
#     'Time': '8:30PM'}],
#   'works': [{'ID': '4012*',
#     'composerName': 'Milhaud,  Darius',
#     'workTitle': 'SUITE FRANÇAISE, OP. 248',
#     'conductorName': 'Previn, André',
#     'soloists': []},
#    {'ID': '52638*1',
#     'composerName': 'Debussy,  Claude',
#     'workTitle': 'NOCTURNES',
#     'movement': 'Nuages ("Clouds")',
#     'conductorName': 'Previn, André',
#     'soloists': []},
#    {'ID': '52638*2',
#     'composerName': 'Debussy,  Claude',
#     'workTitle': 'NOCTURNES',
#     'movement': 'Fêtes ("Festivals")',
#     'conductorName': 'Previn, André',
#     'soloists': []},
#    {'ID': '6616*1',
#     'composerName': 'Canteloube,  Joseph',
#     'workTitle': 'SONGS OF THE AUVERGNE, SERIES 3',
#     'movement': 'No. 1 "Lo fiolairé (La fileuse)"',
#     'conductorName': 'Previn, André',
#     'soloists': []},
#    {'ID': '6616*4',
#     'composerName': 'Canteloube,  Joseph',
#     'workTitle': 'SONGS OF THE AUVERGNE, SERIES 3',
#     'movement': 'No. 4 "Brezairola (Berceuse)"',
#     'conductorName': 'Previn, André',
#     'soloists': []},
#    {'ID': '6614*3',
#     'composerName': 'Canteloube,  Joseph',
#     'workTitle': 'SONGS OF THE AUVERGNE, SERIES 1',
#     'movement': 'No. 3A "L\'aio de rotso (L\'eau de source)"',
#     'conductorName': 'Previn, André',
#     'soloists': []},
#    {'ID': '6614*5',
#     'composerName': 'Canteloube,  Joseph',
#     'workTitle': 'SONGS OF THE AUVERGNE, SERIES 1',
#     'movement': 'No. 3C "Obal, din lou limouzi (La-bas dans le limousin)"',
#     'conductorName': 'Previn, André',
#     'soloists': []},
#    {'ID': '6616*2',
#     'composerName': 'Canteloube,  Joseph',
#     'workTitle': 'SONGS OF THE AUVERGNE, SERIES 3',
#     'movement': 'No. 2 "Passo pel prat (Viens par le pré)"',
#     'conductorName': 'Previn, André',
#     'soloists': []},
#    {'ID': '6616*5',
#     'composerName': 'Canteloube,  Joseph',
#     'workTitle': 'SONGS OF THE AUVERGNE, SERIES 3',
#     'movement': 'No. 5 "Malurous qu\'o uno fenno (Malheureux qui a une femme)"',
#     'conductorName': 'Previn, André',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '3077*',
#     'composerName': 'Offenbach,  Jacques',
#     'workTitle': 'GAITE PARISIENNE (ARR. Rosenthal)',
#     'conductorName': 'Previn, André',
#     'soloists': []},
#    {'ID': '50387*',
#     'composerName': 'Gershwin,  George',
#     'workTitle': 'AMERICAN IN PARIS, AN (TRADITIONAL VERSION) (ARR. Campbell-Watson)',
#     'conductorName': 'Previn, André',
#     'soloists': []}]},
#  {'id': 'bc373c9d-dc89-4e67-9194-7df99a01d66b-0.1',
#   'programID': '6326',
#   'orchestra': 'New York Philharmonic',
#   'season': '1962-63',
#   'concerts': [{'eventType': 'Promenade',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Philharmonic Hall',
#     'Date': '1963-06-19T04:00:00Z',
#     'Time': '8:30PM'},
#    {'eventType': 'Promenade',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Philharmonic Hall',
#     'Date': '1963-06-20T04:00:00Z',
#     'Time': '8:30PM'},
#    {'eventType': 'Promenade',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Philharmonic Hall',
#     'Date': '1963-06-21T04:00:00Z',
#     'Time': '8:30PM'}],
#   'works': [{'ID': '180*3',
#     'composerName': 'Fernandez [Fernândez],  Oscar  Lorenzo',
#     'workTitle': 'REISADO DO PASTOREIO SUITE',
#     'movement': '"Batuque" (Danza di Negri)',
#     'conductorName': 'Gould, Morton',
#     'soloists': []},
#    {'ID': '3269*',
#     'composerName': 'Turina,  Joaquin',
#     'workTitle': 'LA ORACIÓN DEL TORERO, OP. 34',
#     'conductorName': 'Gould, Morton',
#     'soloists': []},
#    {'ID': '53397*',
#     'composerName': 'Falla,  Manuel  de',
#     'workTitle': 'EL AMOR BRUJO (REV. 1924)',
#     'conductorName': 'Gould, Morton',
#     'soloists': [{'soloistName': 'Ballet Espanol Ximenez-Vargas',
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Brice, Carol',
#       'soloistInstrument': 'Contralto',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '50532*',
#     'composerName': 'Gould,  Morton',
#     'workTitle': 'LATIN-AMERICAN SYMPHONETTE',
#     'conductorName': 'Gould, Morton',
#     'soloists': []},
#    {'ID': '51651*',
#     'composerName': 'Rimsky-Korsakov,  Nikolai',
#     'workTitle': 'CAPRICCIO ESPAGNOL, OP. 34',
#     'conductorName': 'Gould, Morton',
#     'soloists': []}]},
#  {'id': 'd1edd2c2-2d99-45c9-a739-6beb06cab8ae-0.1',
#   'programID': '6331',
#   'orchestra': 'New York Philharmonic',
#   'season': '1962-63',
#   'concerts': [{'eventType': 'Promenade',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Philharmonic Hall',
#     'Date': '1963-06-22T04:00:00Z',
#     'Time': '8:30PM'},
#    {'eventType': 'Promenade',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Philharmonic Hall',
#     'Date': '1963-06-23T04:00:00Z',
#     'Time': '8:30PM'}],
#   'works': [{'ID': '257*1',
#     'composerName': 'Menotti,  Gian  Carlo',
#     'workTitle': 'AMELIA GOES TO THE BALL',
#     'movement': 'Overture',
#     'conductorName': 'Gould, Morton',
#     'soloists': []},
#    {'ID': '50728*',
#     'composerName': 'Weber,  Carl  Maria Von',
#     'workTitle': 'INVITATION TO THE DANCE (ARR. Berlioz)',
#     'conductorName': 'Gould, Morton',
#     'soloists': []},
#    {'ID': '52293*',
#     'composerName': 'Copland,  Aaron',
#     'workTitle': 'DANCE SYMPHONY',
#     'conductorName': 'Gould, Morton',
#     'soloists': []},
#    {'ID': '51391*17',
#     'composerName': 'Glazunov,  Alexander',
#     'workTitle': 'RAYMONDA, OP. 57',
#     'movement': 'Divertissement: Pas de Dix (Ballet Music)',
#     'conductorName': 'Gould, Morton',
#     'soloists': [{'soloistName': 'Wilde, Patricia',
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Fernandez, Royes',
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '51427*',
#     'composerName': 'Gould,  Morton',
#     'workTitle': 'TAP DANCE CONCERTO',
#     'conductorName': 'Gould, Morton',
#     'soloists': [{'soloistName': 'Daniels, Danny',
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'}]},
#    {'ID': '51590*',
#     'composerName': 'Ravel,  Maurice',
#     'workTitle': 'PAVANE POUR UNE INFANTE DEFUNTE',
#     'conductorName': 'Gould, Morton',
#     'soloists': []},
#    {'ID': '715*',
#     'composerName': 'Ravel,  Maurice',
#     'workTitle': 'VALSE, LA',
#     'conductorName': 'Gould, Morton',
#     'soloists': []}]}]

# %%
print(len(repeated_programs))
# Out:
# 262

# %%
single_performance_subscription_concerts = [p for p in programs['programs'] 
                                            if len(p['concerts']) == 1
                                            and p['concerts'][0]['eventType'] == 'Subscription Season']
len(single_performance_subscription_concerts)
# Out:
# 186

# %%
single_performance_subscription_concerts
# Out:
# [{'id': 'f26174c5-ef03-479b-867c-ed46149d27a9-0.1',
#   'programID': '7217',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-10-23T04:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '548*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'SINFONIA CONCERTANTE, VLN/VLA/VC, A MAJOR, K.320E [ANH. 104]',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Corigliano, John, Sr.',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'A'},
#      {'soloistName': 'Lincer, William',
#       'soloistInstrument': 'Viola',
#       'soloistRoles': 'A'},
#      {'soloistName': 'Varga, Laszlo',
#       'soloistInstrument': 'Cello',
#       'soloistRoles': 'A'}]},
#    {'ID': '51041*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'CONCERTO, PIANO NO. 16, D MAJOR, K.451',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Serkin, Rudolf',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '51071*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'CONCERTO, PIANO NO. 25, C MAJOR, K.503',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Serkin, Rudolf',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]}]},
#  {'id': '91b1b615-070f-483a-ac17-7fb61ac2a047-0.1',
#   'programID': '7227',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-10-30T04:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '9005*7',
#     'composerName': 'Wagner,  Richard',
#     'workTitle': 'SIEGFRIED, WWV 86C',
#     'movement': 'Waldweben (Forest Murmurs)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '4346*', 'interval': 'Intermission-Short', 'soloists': []},
#    {'ID': '9006*2',
#     'composerName': 'Wagner,  Richard',
#     'workTitle': 'GOTTERDAMMERUNG [GÖTTERDÄMMERUNG]',
#     'movement': 'ACT III: COMPLETE',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Varnay, Astrid',
#       'soloistInstrument': 'Soprano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Vinay, Ramon',
#       'soloistInstrument': 'Tenor',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Vichey, Luben',
#       'soloistInstrument': 'Bass',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Harvuot, Clifford',
#       'soloistInstrument': 'Vocalist',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Amara, Lucine',
#       'soloistInstrument': 'Soprano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Vatenissian, Shakeh',
#       'soloistInstrument': 'Vocalist',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Elias, Rosalind',
#       'soloistInstrument': 'Mezzo-Soprano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Glaz, Herta',
#       'soloistInstrument': 'Vocalist',
#       'soloistRoles': 'S'}]}]},
#  {'id': '932e76e7-e837-4151-92a9-5c43964cf0db-0.1',
#   'programID': '4212',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-11-05T05:00:00Z',
#     'Time': '8:45PM'}],
#   'works': [{'ID': '5801*1',
#     'composerName': 'Mendelssohn,  Felix',
#     'workTitle': "MIDSUMMER NIGHT'S DREAM, OP. 61",
#     'movement': 'Overture',
#     'conductorName': 'Rudolf, Max',
#     'soloists': []},
#    {'ID': '50128*',
#     'composerName': 'Hindemith,  Paul',
#     'workTitle': 'MATHIS DER MALER (SYMPHONY)',
#     'conductorName': 'Rudolf, Max',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '51870*',
#     'composerName': 'Brahms,  Johannes',
#     'workTitle': 'SYMPHONY NO. 1 IN C MINOR, OP. 68',
#     'conductorName': 'Rudolf, Max',
#     'soloists': []}]},
#  {'id': '3a2463e6-82a2-4e0b-af61-28d2848a34e1-0.1',
#   'programID': '4216',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-11-06T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '8837*10',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'FIDELIO, OP. 72',
#     'movement': 'Overture',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '51059*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'CONCERTO, PIANO NO. 22, E-FLAT MAJOR, K.482',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Scarpini, Pietro',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '51929*',
#     'composerName': 'Strauss,  Richard',
#     'workTitle': 'ALSO SPRACH ZARATHUSTRA, OP. 30',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '11775*2',
#     'composerName': 'Falla,  Manuel  de',
#     'workTitle': 'THREE-CORNERED HAT (EL SOMBRERO DE TRES PICOS), SUITE NO. 2',
#     'movement': "The Miller's Dance (Farruca)",
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '11775*3',
#     'composerName': 'Falla,  Manuel  de',
#     'workTitle': 'THREE-CORNERED HAT (EL SOMBRERO DE TRES PICOS), SUITE NO. 2',
#     'movement': 'Final Dance (Jota)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': '106233be-13cb-408c-b003-9f6a4a8754fe-0.1',
#   'programID': '4225',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-11-12T05:00:00Z',
#     'Time': '8:45PM'}],
#   'works': [{'ID': '50746*',
#     'composerName': 'Weber,  Carl  Maria Von',
#     'workTitle': 'SYMPHONY NO. 1, C MAJOR, J. 50',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '52915*',
#     'composerName': 'Schuman,  William',
#     'workTitle': 'JUDITH',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '3093*',
#     'composerName': 'Saint-Saens [Saint-Saëns],  Camille',
#     'workTitle': 'CONCERTO, PIANO, NO. 2, G MINOR, OP. 22',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Casadesus, Jean',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '1898*1',
#     'composerName': 'Strauss,  Richard',
#     'workTitle': 'SALOME, OP. 54',
#     'movement': 'Dance of the Seven Veils',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': 'f1cf78b1-cb7e-4c45-af0e-0692ddb8131b-0.1',
#   'programID': '4229',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-11-13T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '3354*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'CONCERTO, PIANO NO. 10, E-FLAT MAJOR, K.316A (OLD K.365) (2 PIANOS)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Casadesus, Gaby',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Casadesus, Robert',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '3093*',
#     'composerName': 'Saint-Saens [Saint-Saëns],  Camille',
#     'workTitle': 'CONCERTO, PIANO, NO. 2, G MINOR, OP. 22',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Casadesus, Jean',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '52915*',
#     'composerName': 'Schuman,  William',
#     'workTitle': 'JUDITH',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '1898*1',
#     'composerName': 'Strauss,  Richard',
#     'workTitle': 'SALOME, OP. 54',
#     'movement': 'Dance of the Seven Veils',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': 'cac7a1c8-e7bb-4740-ad43-8556a5c72d22-0.1',
#   'programID': '4238',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-11-19T05:00:00Z',
#     'Time': '8:45PM'}],
#   'works': [{'ID': '51880*',
#     'composerName': 'Brahms,  Johannes',
#     'workTitle': 'SYMPHONY NO. 3 IN F MAJOR, OP. 90',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '551*',
#     'composerName': 'Schumann,  Robert',
#     'workTitle': 'CONCERTO, PIANO, A MINOR, OP. 54',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': [{'soloistName': 'Deering, Henri',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '3417*',
#     'composerName': 'Debussy,  Claude',
#     'workTitle': 'MER, LA [THE SEA]',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []}]},
#  {'id': '00652e95-4f50-4015-8df0-4524a4c93823-0.1',
#   'programID': '4242',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-11-20T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '52361*',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'CORIOLAN OVERTURE, OP. 62',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []},
#    {'ID': '51880*',
#     'composerName': 'Brahms,  Johannes',
#     'workTitle': 'SYMPHONY NO. 3 IN F MAJOR, OP. 90',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '52502*',
#     'composerName': 'Mendelssohn,  Felix',
#     'workTitle': 'CONCERTO, VIOLIN, E MINOR, OP.64',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': [{'soloistName': 'Elman, Mischa',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '3417*',
#     'composerName': 'Debussy,  Claude',
#     'workTitle': 'MER, LA [THE SEA]',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []}]},
#  {'id': 'cd84e1fa-6e8c-4e4b-8c58-942eb3c27b25-0.1',
#   'programID': '4255',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-11-26T05:00:00Z',
#     'Time': '8:45PM'}],
#   'works': [{'ID': '1867*',
#     'composerName': 'Bach,  Johann  Sebastian',
#     'workTitle': 'SUITE NO. 3, D MAJOR, BWV 1068',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []},
#    {'ID': '51067*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'CONCERTO, PIANO NO. 24, C MINOR, K.491',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': [{'soloistName': 'Casadesus, Robert',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '51356*17',
#     'composerName': 'Berlioz,  Hector',
#     'workTitle': 'ROMEO ET JULIETTE, OP.17',
#     'movement': 'Romeo Alone',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []},
#    {'ID': '51356*14',
#     'composerName': 'Berlioz,  Hector',
#     'workTitle': 'ROMEO ET JULIETTE, OP.17',
#     'movement': "Great festivities in Capulet's palace",
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []},
#    {'ID': '5550*',
#     'composerName': "Indy,  Vincent  d'",
#     'workTitle': 'SYMPHONY ON A FRENCH MOUNTAIN AIR, OP. 25',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': [{'soloistName': 'Casadesus, Robert',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]}]},
#  {'id': '0f496c63-ea8d-4b23-9e6f-510fb363698c-0.1',
#   'programID': '4261',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-11-27T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '52364*1',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'EGMONT, OP.84',
#     'movement': 'Overture',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []},
#    {'ID': '51067*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'CONCERTO, PIANO NO. 24, C MINOR, K.491',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': [{'soloistName': 'Casadesus, Robert',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '51356*17',
#     'composerName': 'Berlioz,  Hector',
#     'workTitle': 'ROMEO ET JULIETTE, OP.17',
#     'movement': 'Romeo Alone',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []},
#    {'ID': '51356*14',
#     'composerName': 'Berlioz,  Hector',
#     'workTitle': 'ROMEO ET JULIETTE, OP.17',
#     'movement': "Great festivities in Capulet's palace",
#     'conductorName': 'Monteux, Pierre',
#     'soloists': []},
#    {'ID': '5550*',
#     'composerName': "Indy,  Vincent  d'",
#     'workTitle': 'SYMPHONY ON A FRENCH MOUNTAIN AIR, OP. 25',
#     'conductorName': 'Monteux, Pierre',
#     'soloists': [{'soloistName': 'Casadesus, Robert',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]}]},
#  {'id': 'e21a77cd-960a-477a-8404-b8d1a737b897-0.1',
#   'programID': '1148',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-12-03T05:00:00Z',
#     'Time': '8:45PM'}],
#   'works': [{'ID': '52389*',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'LEONORE OVERTURE NO. 3, OP. 72B',
#     'conductorName': 'Szell, George',
#     'soloists': []},
#    {'ID': '50874*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'ADAGIO, VIOLIN, E MAJOR, K.261',
#     'conductorName': 'Szell, George',
#     'soloists': [{'soloistName': 'Szigeti, Joseph',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '51091*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'CONCERTO, VIOLIN NO. 3, G MAJOR, K.216',
#     'conductorName': 'Szell, George',
#     'soloists': [{'soloistName': 'Szigeti, Joseph',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '52449*',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'SYMPHONY NO. 6 IN F MAJOR, OP.68 (PASTORAL)',
#     'conductorName': 'Szell, George',
#     'soloists': []}]},
#  {'id': '560707f5-3bce-4071-9b2e-03d92786e257-0.1',
#   'programID': '1152',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-12-04T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '52449*',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'SYMPHONY NO. 6 IN F MAJOR, OP.68 (PASTORAL)',
#     'conductorName': 'Szell, George',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '50874*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'ADAGIO, VIOLIN, E MAJOR, K.261',
#     'conductorName': 'Szell, George',
#     'soloists': [{'soloistName': 'Szigeti, Joseph',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '51091*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'CONCERTO, VIOLIN NO. 3, G MAJOR, K.216',
#     'conductorName': 'Szell, George',
#     'soloists': [{'soloistName': 'Szigeti, Joseph',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '52389*',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'LEONORE OVERTURE NO. 3, OP. 72B',
#     'conductorName': 'Szell, George',
#     'soloists': []}]},
#  {'id': '13c7cbf5-6689-42bb-90b4-883111a1f44e-0.1',
#   'programID': '1160',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-12-10T05:00:00Z',
#     'Time': '8:45PM'}],
#   'works': [{'ID': '8834*3',
#     'composerName': 'Weber,  Carl  Maria Von',
#     'workTitle': 'OBERON',
#     'movement': 'Overture',
#     'conductorName': 'Szell, George',
#     'soloists': []},
#    {'ID': '3441*',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'CONCERTO, PIANO, NO. 2, B FLAT MAJOR, OP.19',
#     'conductorName': 'Szell, George',
#     'soloists': [{'soloistName': 'Fleisher, Leon',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '53254*',
#     'composerName': 'Sibelius,  Jean',
#     'workTitle': 'SYMPHONY NO. 2, D MAJOR, OP. 43',
#     'conductorName': 'Szell, George',
#     'soloists': []}]},
#  {'id': '2ba72b2f-6890-4bce-b55f-5bf157456b30-0.1',
#   'programID': '1163',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-12-11T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '53254*',
#     'composerName': 'Sibelius,  Jean',
#     'workTitle': 'SYMPHONY NO. 2, D MAJOR, OP. 43',
#     'conductorName': 'Szell, George',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '3441*',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'CONCERTO, PIANO, NO. 2, B FLAT MAJOR, OP.19',
#     'conductorName': 'Szell, George',
#     'soloists': [{'soloistName': 'Fleisher, Leon',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '8834*3',
#     'composerName': 'Weber,  Carl  Maria Von',
#     'workTitle': 'OBERON',
#     'movement': 'Overture',
#     'conductorName': 'Szell, George',
#     'soloists': []}]},
#  {'id': '71df1718-fc0f-4538-9d05-af728a8a4f74-0.1',
#   'programID': '1170',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Hartford, CT',
#     'Venue': 'Bushnell Auditorium',
#     'Date': '1955-12-20T05:00:00Z',
#     'Time': 'None'}],
#   'works': [{'ID': '52460*',
#     'composerName': 'Couperin,  Francois [François]',
#     'workTitle': 'PRELUDE AND ALLEGRO (ARR. Milhaud)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '50746*',
#     'composerName': 'Weber,  Carl  Maria Von',
#     'workTitle': 'SYMPHONY NO. 1, C MAJOR, J. 50',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '51897*',
#     'composerName': 'Shostakovich,  Dmitri',
#     'workTitle': 'SYMPHONY NO. 10, OP. 93',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': 'bbf28bcd-7cbe-4706-b3a6-aed6d0fd55ef-0.1',
#   'programID': '1184',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-12-25T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '50064*',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SYMPHONY NO. 4, F MINOR, OP. 36',
#     'conductorName': 'Szell, George',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '4073*',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'CONCERTO, VIOLIN, D MAJOR, OP.35',
#     'conductorName': 'Szell, George',
#     'soloists': [{'soloistName': 'Morini, Erica',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]}]},
#  {'id': '90716463-370e-4524-8bf3-5bb7df444646-0.1',
#   'programID': '1195',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1955-12-31T05:00:00Z',
#     'Time': '8:45PM'}],
#   'works': [{'ID': '51461*',
#     'composerName': 'Bizet,  Georges',
#     'workTitle': "L'ARLESIENNE: SUITE NO. 1",
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '3077*',
#     'composerName': 'Offenbach,  Jacques',
#     'workTitle': 'GAITE PARISIENNE (ARR. Rosenthal)',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '4020*',
#     'composerName': 'Miyagi,  Michio',
#     'workTitle': 'SEA OF THE SPRING',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Yuize, Shinichi',
#       'soloistInstrument': 'Koto',
#       'soloistRoles': 'A'},
#      {'soloistName': 'Wummer, John',
#       'soloistInstrument': 'Flute',
#       'soloistRoles': 'A'}]},
#    {'ID': '569*',
#     'composerName': 'Konoye,  Hidemaro',
#     'workTitle': 'ETENRAKU',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '219*1',
#     'composerName': 'Kay,  Hershy',
#     'workTitle': 'WESTERN SYMPHONY',
#     'movement': '"Saturday Night"',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '3667*',
#     'composerName': 'Kern,  Jerome',
#     'workTitle': 'SHOW BOAT: SCENARIO FOR ORCHESTRA',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '2839*',
#     'composerName': 'Traditional,',
#     'workTitle': 'AULD LANG SYNE',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '3924*3',
#     'composerName': 'Falla,  Manuel  de',
#     'workTitle': 'VIDA BREVE, LA',
#     'movement': 'Spanish Dance No. 1 (arr. Chapelier)',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '2682*',
#     'composerName': 'Borodin,  Alexander',
#     'workTitle': 'NOCTURNE (ARR. Sargent)',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '3820*',
#     'composerName': 'Sousa,  John  Philip',
#     'workTitle': 'STARS AND STRIPES FOREVER',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '3077*1',
#     'composerName': 'Offenbach,  Jacques',
#     'workTitle': 'GAITE PARISIENNE (ARR. Rosenthal)',
#     'movement': 'No. 23 Barcarolle (Allegro moderato)',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []}]},
#  {'id': 'a4100a00-1b78-4779-bdc5-591a7205cca6-0.1',
#   'programID': '4872',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-01-01T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '1252*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'DON GIOVANNI: OVERTURE, K.527 (ARR. Busoni)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '51099*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'CONCERTO, VIOLIN NO. 5, A MAJOR, K.219',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Oistrakh, David',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '53147*',
#     'composerName': 'Shostakovich,  Dmitri',
#     'workTitle': 'CONCERTO, VIOLIN, NO. 1, OP. 99 (OP. 77)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Oistrakh, David',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '52684*',
#     'composerName': 'Saint-Saens [Saint-Saëns],  Camille',
#     'workTitle': "JEUNESSE D'HERCULE, LA, OP. 50",
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': '1ed7a4c2-4f22-4fa7-a408-4f2cc9464ae4-0.1',
#   'programID': '4882',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-01-08T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '52709*',
#     'composerName': 'Saint-Saens [Saint-Saëns],  Camille',
#     'workTitle': 'PHAETON, OP. 39',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '53496*',
#     'composerName': 'Foss,  Lukas',
#     'workTitle': 'SONG OF SONGS',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Davis, Ellabelle',
#       'soloistInstrument': 'Soprano',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '50322*',
#     'composerName': 'Vaughan Williams,  Ralph',
#     'workTitle': 'SYMPHONY NO. 4 IN F MINOR',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '881*1',
#     'composerName': 'Skalkottas,  Nikos',
#     'workTitle': '36 GREEK DANCES',
#     'movement': 'Series 1: IV. Peloponnissiakos',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '881*2',
#     'composerName': 'Skalkottas,  Nikos',
#     'workTitle': '36 GREEK DANCES',
#     'movement': 'Series I: III. Ipirotikos',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '881*3',
#     'composerName': 'Skalkottas,  Nikos',
#     'workTitle': '36 GREEK DANCES',
#     'movement': 'Series 3: I. Hostianos',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '881*4',
#     'composerName': 'Skalkottas,  Nikos',
#     'workTitle': '36 GREEK DANCES',
#     'movement': 'Kleftikos (Unspecified)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': 'c65ab7fc-c02b-4400-9cb4-531f8a041884-0.1',
#   'programID': '4891',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-01-14T05:00:00Z',
#     'Time': '8:45PM'}],
#   'works': [{'ID': '50335*',
#     'composerName': 'Franck,  César',
#     'workTitle': 'SYMPHONY IN D MINOR',
#     'conductorName': 'Autori, Franco',
#     'soloists': []},
#    {'ID': '4073*',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'CONCERTO, VIOLIN, D MAJOR, OP.35',
#     'conductorName': 'Autori, Franco',
#     'soloists': [{'soloistName': 'Piastro, Mishel',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '51108*',
#     'composerName': 'Bartok [Bartók],  Béla',
#     'workTitle': 'MIKROKOSMOS SUITE (ARR. Serly)',
#     'conductorName': 'Autori, Franco',
#     'soloists': []}]},
#  {'id': 'a26c2ec0-cde0-4431-9148-1ab1e4f011ff-0.1',
#   'programID': '4894',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-01-15T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '51870*',
#     'composerName': 'Brahms,  Johannes',
#     'workTitle': 'SYMPHONY NO. 1 IN C MINOR, OP. 68',
#     'conductorName': 'Autori, Franco',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '4073*',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'CONCERTO, VIOLIN, D MAJOR, OP.35',
#     'conductorName': 'Autori, Franco',
#     'soloists': [{'soloistName': 'Piastro, Mishel',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '51108*',
#     'composerName': 'Bartok [Bartók],  Béla',
#     'workTitle': 'MIKROKOSMOS SUITE (ARR. Serly)',
#     'conductorName': 'Autori, Franco',
#     'soloists': []}]},
#  {'id': 'ce0dcee3-5b31-4c60-a81b-eb2a726a2f7c-0.1',
#   'programID': '4907',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-01-28T05:00:00Z',
#     'Time': '8:45PM'}],
#   'works': [{'ID': '9181*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'IDOMENEO, K.366: SUITE (ARR. Busoni)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '51107*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'CONCERTO, VIOLIN NO. 7, D MAJOR, K.271I (OLD K.271A)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Bagarotti, Giovanni',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '53071*',
#     'composerName': 'Schumann,  Robert',
#     'workTitle': 'SYMPHONY NO. 2, C MAJOR, OP. 61',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': 'f3491c73-ca24-4a29-beda-c6dd85b8b7c3-0.1',
#   'programID': '4913',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-01-29T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '588*',
#     'composerName': 'Buxtehude,  Dietrich',
#     'workTitle': 'CHACONNE, E MINOR (ARR. Chavez [Chávez])',
#     'conductorName': 'Chavez [Chávez], Carlos',
#     'soloists': []},
#    {'ID': '52337*',
#     'composerName': 'Chavez [Chávez],  Carlos',
#     'workTitle': 'SYMPHONY NO. 3',
#     'conductorName': 'Chavez [Chávez], Carlos',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '2190*',
#     'composerName': 'Prokofiev,  Sergei',
#     'workTitle': 'CONCERTO, PIANO, NO. 3, OP. 26, C MAJOR',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Bachauer, Gina',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '3800*',
#     'composerName': 'Bizet,  Georges',
#     'workTitle': "PETITE SUITE: JEUX D'ENFANTS, OP.22",
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '50858*5',
#     'composerName': 'Kodaly [Kodály],  Zoltán',
#     'workTitle': 'HARY JANOS: SUITE',
#     'movement': 'Intermezzo: Andante maestoso, ma con fuoco',
#     'conductorName': 'Mitropoulos, Dimitri;  Chavez [Chávez], Carlos',
#     'soloists': [{'soloistName': 'Koves-Steiner, Toni',
#       'soloistInstrument': 'Cimbalom',
#       'soloistRoles': 'A'}]},
#    {'ID': '50858*6',
#     'composerName': 'Kodaly [Kodály],  Zoltán',
#     'workTitle': 'HARY JANOS: SUITE',
#     'movement': 'Entrance of the Emperor and His Court',
#     'conductorName': 'Mitropoulos, Dimitri;  Chavez [Chávez], Carlos',
#     'soloists': [{'soloistName': 'Koves-Steiner, Toni',
#       'soloistInstrument': 'Cimbalom',
#       'soloistRoles': 'A'}]}]},
#  {'id': '1526d06f-8857-4e98-9583-6f5fa604f24d-0.1',
#   'programID': '1835',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-02-04T05:00:00Z',
#     'Time': '8:45PM'}],
#   'works': [{'ID': '50767*1',
#     'composerName': 'Kabalevsky,  Dmitri',
#     'workTitle': 'COLAS BREUGNON',
#     'movement': 'Overture',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '51590*',
#     'composerName': 'Ravel,  Maurice',
#     'workTitle': 'PAVANE POUR UNE INFANTE DEFUNTE',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '715*',
#     'composerName': 'Ravel,  Maurice',
#     'workTitle': 'VALSE, LA',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '52314*',
#     'composerName': 'Copland,  Aaron',
#     'workTitle': 'LINCOLN PORTRAIT',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Sandburg, Carl',
#       'soloistInstrument': 'Narrator',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '8864*13',
#     'composerName': 'Musorgsky,  Modest',
#     'workTitle': 'KHOVANSHCHINA (ARR. Rimsky-Korsakov)',
#     'movement': 'Prelude',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '2889*1',
#     'composerName': 'Rimsky-Korsakov,  Nikolai',
#     'workTitle': "COQ D'OR, LE: OPERA",
#     'movement': 'Introduction',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '2889*2',
#     'composerName': 'Rimsky-Korsakov,  Nikolai',
#     'workTitle': "COQ D'OR, LE: OPERA",
#     'movement': 'Wedding March',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '598*',
#     'composerName': 'Grofe [Grofé],  Ferde',
#     'workTitle': 'HUDSON RIVER SUITE',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '52834*3',
#     'composerName': 'Grofe [Grofé],  Ferde',
#     'workTitle': 'GRAND CANYON SUITE',
#     'movement': 'On the Trail',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '4053*',
#     'composerName': 'Pierne [Pierné],  Gabriel',
#     'workTitle': 'MARCH OF THE LEAD SOLDIERS, OP. 14, NO. 6',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '604*1',
#     'composerName': 'Kern,  Jerome',
#     'workTitle': 'SHOW BOAT (ARR. Bennett)',
#     'movement': 'Bill',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '53758*3',
#     'composerName': 'Prokofiev,  Sergei',
#     'workTitle': 'LOVE FOR THREE ORANGES: SUITE, OP. 33 A',
#     'movement': 'March (Tempo di Marcia)',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '6396*',
#     'composerName': 'Strauss,  Johann, II',
#     'workTitle': 'TRITSCH-TRATSCH POLKA, OP. 214',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []}]},
#  {'id': '58cec162-65dc-49be-8101-e56ffec8c2b1-0.1',
#   'programID': '1841',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-02-05T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '52313*',
#     'composerName': 'Chausson,  Ernest',
#     'workTitle': 'SYMPHONY IN B FLAT MAJOR, OP. 20',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '52621*',
#     'composerName': 'Barber,  Samuel',
#     'workTitle': "MEDEA'S MEDITATION AND DANCE OF VENGEANCE, OP. 23A",
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '51569*',
#     'composerName': 'Rachmaninoff,  Sergei',
#     'workTitle': 'RHAPSODY ON A THEME OF PAGANINI, OP. 43',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Browning, John',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '52265*1',
#     'composerName': 'Chabrier,  Emmanuel',
#     'workTitle': 'ROI MALGRE LUI, LE',
#     'movement': 'Fête Polonaise',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': '50502620-54ee-4222-a453-c71e59b872b2-0.1',
#   'programID': '1857',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-02-12T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '52132*',
#     'composerName': 'Haydn,  Franz  Joseph',
#     'workTitle': 'SYMPHONY NO. 103, E FLAT MAJOR (DRUMROLL)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '2068*',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'CONCERTO, VIOLIN, D MAJOR, OP.61',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Heifetz, Jascha',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '9000*1',
#     'composerName': 'Wagner,  Richard',
#     'workTitle': 'RIENZI, WWV 49',
#     'movement': 'Overture',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': '59b26bdf-fe9a-4b99-be03-a15a7615f5ee-0.1',
#   'programID': '1875',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-02-18T05:00:00Z',
#     'Time': '8:45PM'}],
#   'works': [{'ID': '607*',
#     'composerName': 'Piket,  Frederick',
#     'workTitle': 'FUNNIES, THE',
#     'conductorName': 'Autori, Franco',
#     'soloists': []},
#    {'ID': '3163*',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'CONCERTO, PIANO, NO. 4, G MAJOR, OP. 58',
#     'conductorName': 'Autori, Franco',
#     'soloists': [{'soloistName': 'Yankoff, Ventsis',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '50064*',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SYMPHONY NO. 4, F MINOR, OP. 36',
#     'conductorName': 'Autori, Franco',
#     'soloists': []}]},
#  {'id': '3c0da09e-9968-4a81-b59b-e7e4ecf62a6b-0.1',
#   'programID': '1882',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-02-19T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '50389*1',
#     'composerName': 'Verdi,  Giuseppe',
#     'workTitle': 'VESPRI SICILIANI, I',
#     'movement': 'Overture',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '51583*',
#     'composerName': 'Bloch,  Ernest',
#     'workTitle': 'SCHELOMO',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Varga, Laszlo',
#       'soloistInstrument': 'Cello',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '2214*',
#     'composerName': 'Rachmaninoff,  Sergei',
#     'workTitle': 'CONCERTO, PIANO, NO. 3, D MINOR, OP. 30',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Malcuzynski, Witold',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '611*',
#     'composerName': 'Bach,  Johann  Sebastian',
#     'workTitle': 'FANTASIA AND FUGUE, G MINOR, BWV 542 (ARR. Mitropoulos)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': '18bd9464-a67b-424a-9bcc-66c9a087ce82-0.1',
#   'programID': '1897',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-02-25T05:00:00Z',
#     'Time': '8:45PM'}],
#   'works': [{'ID': '51139*2',
#     'composerName': 'Liszt,  Franz',
#     'workTitle': 'ZWEI EPISODEN AUS LENAUS FAUST',
#     'movement': '"Der Tanz in der Dorfschenke" (Mephisto Waltz No. 1)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '1346*',
#     'composerName': 'Prokofiev,  Sergei',
#     'workTitle': 'CONCERTO, VIOLIN, NO. 1, OP. 19, D MAJOR',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Stern, Isaac',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '618*',
#     'composerName': 'Liebermann,  Rolf',
#     'workTitle': 'MUSIQUE',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Zorina, Vera',
#       'soloistInstrument': 'Narrator',
#       'soloistRoles': 'A'}]},
#    {'ID': '50858*',
#     'composerName': 'Kodaly [Kodály],  Zoltán',
#     'workTitle': 'HARY JANOS: SUITE',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Koves-Steiner, Toni',
#       'soloistInstrument': 'Cimbalom',
#       'soloistRoles': 'A'}]}]},
#  {'id': '329a1bfe-13ff-4fe2-8ce9-94d4979fac36-0.1',
#   'programID': '1904',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-02-26T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '8856*1',
#     'composerName': 'Glinka,  Mikhail',
#     'workTitle': 'RUSLAN AND LUDMILA',
#     'movement': 'Overture',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '1346*',
#     'composerName': 'Prokofiev,  Sergei',
#     'workTitle': 'CONCERTO, VIOLIN, NO. 1, OP. 19, D MAJOR',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Stern, Isaac',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '618*',
#     'composerName': 'Liebermann,  Rolf',
#     'workTitle': 'MUSIQUE',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Zorina, Vera',
#       'soloistInstrument': 'Narrator',
#       'soloistRoles': 'A'}]},
#    {'ID': '51149*',
#     'composerName': 'Liszt,  Franz',
#     'workTitle': 'PRELUDES, LES (SYMPHONIC POEM NO. 3)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '51139*2',
#     'composerName': 'Liszt,  Franz',
#     'workTitle': 'ZWEI EPISODEN AUS LENAUS FAUST',
#     'movement': '"Der Tanz in der Dorfschenke" (Mephisto Waltz No. 1)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': '707374f9-bb5a-4bfd-9c2a-a57affedd3b2-0.1',
#   'programID': '6229',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-03-03T05:00:00Z',
#     'Time': '8:45PM'}],
#   'works': [{'ID': '50014*',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'NUTCRACKER, THE: SUITE, OP. 71A',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '50025*',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'ROMEO AND JULIET, FANTASY-OVERTURE',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '50051*1',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SWAN LAKE: SUITE, OP.20A',
#     'movement': 'Scene: Moderato (from Act II)',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '50051*2',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SWAN LAKE: SUITE, OP.20A',
#     'movement': 'Waltz: Tempo di valse (from Act I)',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '8958*20',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SWAN LAKE: BALLET',
#     'movement': 'Scene: Moderato, Act II, No. 14',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '8958*5',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SWAN LAKE: BALLET',
#     'movement': 'Scène et Finale (Act IV, No. 28 plus the first 26 bars of Act IV, No. 29 Finale]',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '8982*2',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'PIQUE DAME (QUEEN OF SPADES)',
#     'movement': 'Suite for Orchestra (selections by Kostelanetz)',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '50031*1',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SLEEPING BEAUTY: SUITE, OP. 66A',
#     'movement': 'Introduction. The Lilac Fairy',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '50031*5',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SLEEPING BEAUTY: SUITE, OP. 66A',
#     'movement': 'Waltz',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '4875*',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'ANDANTE CANTABILE FOR ORCHESTRA, OP. 11 (ARR. Tchaikovsky)',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '50043*4',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SUITE NO. 1, D MINOR, OP.43',
#     'movement': '4. Marche Miniature: Moderato con moto',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '891*',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'NONE BUT THE LONELY HEART, OP. 6 NO. 6 (ARR. ORCHESTRA)',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '52625*26',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'NUTCRACKER, THE',
#     'movement': 'Final Waltz and Apotheosis, Act IIg',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '8958*3',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SWAN LAKE: BALLET',
#     'movement': 'Wedding Dance, Act III, No. 16',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '50031*4',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SLEEPING BEAUTY: SUITE, OP. 66A',
#     'movement': 'Panorama',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []}]},
#  {'id': 'e5f55ed7-2a1a-49ae-abac-1c8af5ac3e84-0.1',
#   'programID': '6242',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-03-17T05:00:00Z',
#     'Time': '8:45PM'}],
#   'works': [{'ID': '51502*',
#     'composerName': 'Bizet,  Georges',
#     'workTitle': 'SYMPHONY IN C MAJOR',
#     'conductorName': 'Schippers, Thomas',
#     'soloists': []},
#    {'ID': '4401*',
#     'composerName': 'Menotti,  Gian  Carlo',
#     'workTitle': 'ISLAND GOD, THE: TWO INTERLUDES',
#     'conductorName': 'Schippers, Thomas',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '51887*',
#     'composerName': 'Shostakovich,  Dmitri',
#     'workTitle': 'SYMPHONY NO.  1, OP. 10',
#     'conductorName': 'Schippers, Thomas',
#     'soloists': []},
#    {'ID': '9007*17',
#     'composerName': 'Wagner,  Richard',
#     'workTitle': 'MEISTERSINGER, DIE, WWV 96',
#     'movement': 'Prelude to Act I',
#     'conductorName': 'Schippers, Thomas',
#     'soloists': []}]},
#  {'id': '36c93aa5-047d-4289-b8d7-28729711ddec-0.1',
#   'programID': '6250',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-03-24T05:00:00Z',
#     'Time': '8:45PM'}],
#   'works': [{'ID': '50422*',
#     'composerName': 'Vivaldi,  Antonio',
#     'workTitle': 'CONCERTO GROSSO, D MINOR, RV 565 (ARR. Siloti)',
#     'conductorName': 'Cantelli, Guido',
#     'soloists': []},
#    {'ID': '53078*',
#     'composerName': 'Schumann,  Robert',
#     'workTitle': 'SYMPHONY NO. 4, D MINOR, OP. 120',
#     'conductorName': 'Cantelli, Guido',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '51985*',
#     'composerName': 'Britten,  Benjamin',
#     'workTitle': 'SINFONIA DA REQUIEM, OP. 20',
#     'conductorName': 'Cantelli, Guido',
#     'soloists': []},
#    {'ID': '51710*1',
#     'composerName': 'Rossini,  Gioachino',
#     'workTitle': 'SEMIRAMIDE',
#     'movement': 'Overture',
#     'conductorName': 'Cantelli, Guido',
#     'soloists': []}]},
#  {'id': 'bd6c1f14-2af1-41e8-9020-50bd482886ad-0.1',
#   'programID': '6252',
#   'orchestra': 'New York Philharmonic',
#   'season': '1955-56',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1956-03-25T05:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '50422*',
#     'composerName': 'Vivaldi,  Antonio',
#     'workTitle': 'CONCERTO GROSSO, D MINOR, RV 565 (ARR. Siloti)',
#     'conductorName': 'Cantelli, Guido',
#     'soloists': []},
#    {'ID': '3548*',
#     'composerName': 'Beethoven,  Ludwig  van',
# ...
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Corigliano, John, Sr.',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'A'},
#      {'soloistName': 'Varga, Laszlo',
#       'soloistInstrument': 'Cello',
#       'soloistRoles': 'A'}]},
#    {'ID': '8958*4',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SWAN LAKE: BALLET',
#     'movement': "Pas d'action (White Swan) [Act II, No. 13, Var. V, abridged ]",
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Wilde, Patricia',
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Ludlow, Conrad',
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Corigliano, John, Sr.',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'A'},
#      {'soloistName': 'Varga, Laszlo',
#       'soloistInstrument': 'Cello',
#       'soloistRoles': 'A'}]},
#    {'ID': '8958*10',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SWAN LAKE: BALLET',
#     'movement': 'Introduction/Opening Scene, Act II, No. 10',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Wilde, Patricia',
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Ludlow, Conrad',
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Corigliano, John, Sr.',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'A'},
#      {'soloistName': 'Varga, Laszlo',
#       'soloistInstrument': 'Cello',
#       'soloistRoles': 'A'}]},
#    {'ID': '8958*9',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SWAN LAKE: BALLET',
#     'movement': "Siegfried's Solo, Act II",
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Wilde, Patricia',
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Ludlow, Conrad',
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Corigliano, John, Sr.',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'A'},
#      {'soloistName': 'Varga, Laszlo',
#       'soloistInstrument': 'Cello',
#       'soloistRoles': 'A'}]},
#    {'ID': '8958*14',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SWAN LAKE: BALLET',
#     'movement': "Odette's Solo, Act II, No. 13/II",
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Wilde, Patricia',
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Ludlow, Conrad',
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Corigliano, John, Sr.',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'A'},
#      {'soloistName': 'Varga, Laszlo',
#       'soloistInstrument': 'Cello',
#       'soloistRoles': 'A'}]},
#    {'ID': '8958*15',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SWAN LAKE: BALLET',
#     'movement': 'Coda (Siegfried + Odette), Act II, 13/VII',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Wilde, Patricia',
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Ludlow, Conrad',
#       'soloistInstrument': 'Dancer',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Corigliano, John, Sr.',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'A'},
#      {'soloistName': 'Varga, Laszlo',
#       'soloistInstrument': 'Cello',
#       'soloistRoles': 'A'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '8982*2',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'PIQUE DAME (QUEEN OF SPADES)',
#     'movement': 'Suite for Orchestra (selections by Kostelanetz)',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '50018*',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'OVERTURE, 1812, OP. 49',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '8958*13',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SWAN LAKE: BALLET',
#     'movement': 'Unspecified Waltz',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '891*',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'NONE BUT THE LONELY HEART, OP. 6 NO. 6 (ARR. ORCHESTRA)',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '52625*26',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'NUTCRACKER, THE',
#     'movement': 'Final Waltz and Apotheosis, Act IIg',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '54118*',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'FESTIVAL CORONATION MARCH (MARCHE SOLENNELLE)',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '8958*12',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'SWAN LAKE: BALLET',
#     'movement': 'Unspecified Pas de Deux',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []}]},
#  {'id': 'eeb2f14a-ce73-4aaa-9603-bdfef7922ca6-0.1',
#   'programID': '3251',
#   'orchestra': 'New York Philharmonic',
#   'season': '1962-63',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Philharmonic Hall',
#     'Date': '1962-09-23T04:00:00Z',
#     'Time': '9:00PM'}],
#   'works': [{'ID': '3965*',
#     'composerName': 'Anthem,',
#     'workTitle': 'UNITED STATES',
#     'conductorName': 'Bernstein, Leonard',
#     'soloists': []},
#    {'ID': '52402*2',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'MISSA SOLEMNIS IN D MAJOR, OP.123',
#     'movement': 'Gloria',
#     'conductorName': 'Bernstein, Leonard',
#     'soloists': [{'soloistName': 'Farrell, Eileen',
#       'soloistInstrument': 'Soprano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Verrett, Shirley',
#       'soloistInstrument': 'Mezzo-Soprano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Vickers, Jon',
#       'soloistInstrument': 'Tenor',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Bell, Donald',
#       'soloistInstrument': 'Bass-Baritone',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Schola Cantorum of NY',
#       'soloistInstrument': 'Chorus',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Juilliard Chorus',
#       'soloistInstrument': 'Chorus',
#       'soloistRoles': 'S'}]},
#    {'ID': '52292*',
#     'composerName': 'Copland,  Aaron',
#     'workTitle': 'CONNOTATIONS',
#     'conductorName': 'Bernstein, Leonard',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '50310*',
#     'composerName': 'Vaughan Williams,  Ralph',
#     'workTitle': 'SERENADE TO MUSIC',
#     'conductorName': 'Bernstein, Leonard',
#     'soloists': [{'soloistName': 'Addison, Adele',
#       'soloistInstrument': 'Soprano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Amara, Lucine',
#       'soloistInstrument': 'Soprano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Farrell, Eileen',
#       'soloistInstrument': 'Soprano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Chookasian, Lili',
#       'soloistInstrument': 'Mezzo-Soprano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Tourel, Jennie',
#       'soloistInstrument': 'Mezzo-Soprano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Verrett, Shirley',
#       'soloistInstrument': 'Mezzo-Soprano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Bressler, Charles',
#       'soloistInstrument': 'Tenor',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Tucker, Richard',
#       'soloistInstrument': 'Tenor',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Vickers, Jon',
#       'soloistInstrument': 'Tenor',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Bell, Donald',
#       'soloistInstrument': 'Bass-Baritone',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Flagello, Ezio',
#       'soloistInstrument': 'Bass-Baritone',
#       'soloistRoles': 'S'},
#      {'soloistName': 'London, George',
#       'soloistInstrument': 'Bass-Baritone',
#       'soloistRoles': 'S'}]},
#    {'ID': '52878*1',
#     'composerName': 'Mahler,  Gustav',
#     'workTitle': 'SYMPHONY NO.  8 IN E FLAT MAJOR (SYMPHONY OF A THOUSAND)',
#     'movement': {'_': 'Hymn:', 'em': 'Veni, creator spiritus'},
#     'conductorName': 'Bernstein, Leonard',
#     'soloists': [{'soloistName': 'Addison, Adele',
#       'soloistInstrument': 'Soprano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Amara, Lucine',
#       'soloistInstrument': 'Soprano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Chookasian, Lili',
#       'soloistInstrument': 'Mezzo-Soprano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Tourel, Jennie',
#       'soloistInstrument': 'Mezzo-Soprano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Tucker, Richard',
#       'soloistInstrument': 'Tenor',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Flagello, Ezio',
#       'soloistInstrument': 'Bass-Baritone',
#       'soloistRoles': 'S'},
#      {'soloistName': 'London, George',
#       'soloistInstrument': 'Bass-Baritone',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Schola Cantorum of NY',
#       'soloistInstrument': 'Chorus',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Juilliard Chorus',
#       'soloistInstrument': 'Chorus',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Columbus Boychoir',
#       'soloistInstrument': 'Boys Choir',
#       'soloistRoles': 'S'}]}]},
#  {'id': '4c86c972-96a7-47b8-a9a4-4c3a48af40aa-0.1',
#   'programID': '3254',
#   'orchestra': 'New York Philharmonic',
#   'season': '1962-63',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Philharmonic Hall',
#     'Date': '1962-09-26T04:00:00Z',
#     'Time': '8:30PM'}],
#   'works': [{'ID': '99*',
#     'composerName': 'Strauss,  Richard',
#     'workTitle': 'FESTIVAL PRELUDE',
#     'conductorName': 'Bernstein, Leonard',
#     'soloists': [{'soloistName': 'Biggs, E. Power',
#       'soloistInstrument': 'Organ',
#       'soloistRoles': 'S'}]},
#    {'ID': '2062*',
#     'composerName': 'Haydn,  Franz  Joseph',
#     'workTitle': 'SINFONIA CONCERTANTE, B-FLAT MAJOR, H. I:105',
#     'conductorName': 'Bernstein, Leonard',
#     'soloists': [{'soloistName': 'Corigliano, John, Sr.',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'A'},
#      {'soloistName': 'Stern, Carl',
#       'soloistInstrument': 'Cello',
#       'soloistRoles': 'A'},
#      {'soloistName': 'Gomberg, Harold',
#       'soloistInstrument': 'Oboe',
#       'soloistRoles': 'A'},
#      {'soloistName': 'Zegler, Manuel',
#       'soloistInstrument': 'Bassoon',
#       'soloistRoles': 'A'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '853*',
#     'composerName': 'Vivaldi,  Antonio',
#     'workTitle': 'CONCERTO, VIOLINS (4),  B MINOR, RV 580',
#     'conductorName': 'Bernstein, Leonard',
#     'soloists': [{'soloistName': 'Fuchs, Joseph',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Gullino, Frank',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Goldberg, Szymon',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Spivakovsky, Tossy',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '955*',
#     'composerName': 'Bach,  Johann  Sebastian',
#     'workTitle': 'CON., HARPSICHORDS, (FOUR), BWV 1065, A MINOR',
#     'conductorName': 'Bernstein, Leonard',
#     'soloists': [{'soloistName': 'Fleisher, Leon',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Frager, Malcolm',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Graffman, Gary',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Istomin, Eugene',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '53708*',
#     'composerName': 'Stravinsky,  Igor',
#     'workTitle': 'SACRE DU PRINTEMPS, LE',
#     'conductorName': 'Bernstein, Leonard',
#     'soloists': []}]},
#  {'id': 'b3922f72-59be-49ec-ab9e-f4fbbb8560ca-0.1',
#   'programID': '5302',
#   'orchestra': 'New York Philharmonic',
#   'season': '1962-63',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Philharmonic Hall',
#     'Date': '1963-01-20T05:00:00Z',
#     'Time': '3:00PM'}],
#   'works': [{'ID': '53116*',
#     'composerName': 'Mennin,  Peter',
#     'workTitle': 'CONCERTATO (MOBY DICK)',
#     'conductorName': 'Bernstein, Leonard',
#     'soloists': []},
#    {'ID': '51072*',
#     'composerName': 'Mozart,  Wolfgang  Amadeus',
#     'workTitle': 'CONCERTO, PIANO NO. 26, D MAJOR, K.537 "CORONATION"',
#     'conductorName': 'Bernstein, Leonard',
#     'soloists': [{'soloistName': 'Block, Michel',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '168*',
#     'composerName': 'Martinu [Martinů],  Bohuslav',
#     'workTitle': 'CONCERTO, STRING QUARTET',
#     'conductorName': 'Bernstein, Leonard',
#     'soloists': [{'soloistName': 'Juilliard String Quartet',
#       'soloistInstrument': 'String Quartet',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Mann, Robert',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'A'},
#      {'soloistName': 'Cohen, Isidore',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'A'},
#      {'soloistName': 'Hillyer, Raphael',
#       'soloistInstrument': 'Viola',
#       'soloistRoles': 'A'},
#      {'soloistName': 'Adam, Claus',
#       'soloistInstrument': 'Cello',
#       'soloistRoles': 'A'}]},
#    {'ID': '715*',
#     'composerName': 'Ravel,  Maurice',
#     'workTitle': 'VALSE, LA',
#     'conductorName': 'Bernstein, Leonard',
#     'soloists': []}]},
#  {'id': '5f9b9cbe-f7e7-44d6-880b-6470b8cd2c99-0.1',
#   'programID': '2267',
#   'orchestra': 'New York Philharmonic',
#   'season': '1962-63',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Philharmonic Hall',
#     'Date': '1963-02-02T05:00:00Z',
#     'Time': '8:30PM'}],
#   'works': [{'ID': '52777*',
#     'composerName': 'Schubert,  Franz',
#     'workTitle': 'SYMPHONY NO. 5, B FLAT MAJOR, D.485',
#     'conductorName': 'Bernstein, Leonard',
#     'soloists': []},
#    {'ID': '52292*',
#     'composerName': 'Copland,  Aaron',
#     'workTitle': 'CONNOTATIONS',
#     'conductorName': 'Bernstein, Leonard',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '51944*',
#     'composerName': 'Strauss,  Richard',
#     'workTitle': 'DON JUAN, OP. 20',
#     'conductorName': 'Bernstein, Leonard',
#     'soloists': []},
#    {'ID': '2407*',
#     'composerName': 'Ravel,  Maurice',
#     'workTitle': 'CONCERTO, PIANO, G MAJOR',
#     'conductorName': 'Bernstein, Leonard',
#     'soloists': [{'soloistName': 'Bernstein, Leonard',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]}]},
#  {'id': 'dc600118-fdb6-4f5b-8b98-e030d64e089e-0.1',
#   'programID': '2272',
#   'orchestra': 'New York Philharmonic',
#   'season': '1962-63',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Philharmonic Hall',
#     'Date': '1963-02-03T05:00:00Z',
#     'Time': '3:00PM'}],
#   'works': [{'ID': '52777*',
#     'composerName': 'Schubert,  Franz',
#     'workTitle': 'SYMPHONY NO. 5, B FLAT MAJOR, D.485',
#     'conductorName': 'Bernstein, Leonard',
#     'soloists': []},
#    {'ID': '2407*',
#     'composerName': 'Ravel,  Maurice',
#     'workTitle': 'CONCERTO, PIANO, G MAJOR',
#     'conductorName': 'Bernstein, Leonard',
#     'soloists': [{'soloistName': 'Bernstein, Leonard',
#       'soloistInstrument': 'Piano',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '53341*',
#     'composerName': 'Dvorak,  Antonín',
#     'workTitle': 'SYMPHONY NO. 7, D MINOR, OP.70 (OLD NO. 2)',
#     'conductorName': 'Bernstein, Leonard',
#     'soloists': []}]}]

# %%
for program in all_subscription_programs:
    for concert in program['concerts']:
        if concert['eventType'] != 'Subscription Season':
            print(program)

# %%
walton_programs = [p for p in all_subscription_programs if has_works_by(p, 'Walton')]
walton_programs
# Out:
# [{'id': 'ede4acbb-2ad2-4483-b038-d867aa0bd471-0.1',
#   'programID': '2786',
#   'orchestra': 'New York Philharmonic',
#   'season': '1956-57',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1957-02-09T05:00:00Z',
#     'Time': '8:45PM'}],
#   'works': [{'ID': '50840*1',
#     'composerName': 'Wolf-Ferrari,  Ermanno',
#     'workTitle': 'THE SECRET OF SUZANNE',
#     'movement': 'Overture',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '642*7',
#     'composerName': 'Puccini,  Giacomo',
#     'workTitle': 'BOHEME, LA',
#     'movement': 'Orchestral Excerpts (unspecified) (Act I)',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '51149*',
#     'composerName': 'Liszt,  Franz',
#     'workTitle': 'PRELUDES, LES (SYMPHONIC POEM NO. 3)',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '3635*',
#     'composerName': 'Lyadov,  Anatoli',
#     'workTitle': 'ENCHANTED LAKE, THE, OP. 62',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '50679*1',
#     'composerName': 'Walton,  William',
#     'workTitle': 'FACADE (FAÇADE): SUITE NO. 1',
#     'movement': 'I. Polka',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '50679*2',
#     'composerName': 'Walton,  William',
#     'workTitle': 'FACADE (FAÇADE): SUITE NO. 1',
#     'movement': 'II. Valse',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '50679*3',
#     'composerName': 'Walton,  William',
#     'workTitle': 'FACADE (FAÇADE): SUITE NO. 1',
#     'movement': 'III. Swiss Jodelling Song; Lento',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '50679*4',
#     'composerName': 'Walton,  William',
#     'workTitle': 'FACADE (FAÇADE): SUITE NO. 1',
#     'movement': 'IV. Tango-Pasodoblé; Lento',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '52097*5',
#     'composerName': 'Walton,  William',
#     'workTitle': 'FACADE (FAÇADE): SUITE NO. 2',
#     'movement': 'V. Popular Song; Grazioso',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '50679*5',
#     'composerName': 'Walton,  William',
#     'workTitle': 'FACADE (FAÇADE): SUITE NO. 1',
#     'movement': 'V. Tarantella-Sevillana',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '54028*',
#     'composerName': 'Strauss,  Johann, Jr. & Josef',
#     'workTitle': 'PIZZICATO POLKA',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '3261*',
#     'composerName': 'Strauss,  Johann, II',
#     'workTitle': 'GESCHICHTEN AUS DEM WIENERWALD (TALES FROM THE VIENNA WOODS), OP. 325',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Dietschmann, Franz',
#       'soloistInstrument': 'Zither',
#       'soloistRoles': 'A'}]},
#    {'ID': '53457*',
#     'composerName': 'Strauss,  Johann, II',
#     'workTitle': 'PERPETUUM MOBILE, OP. 257',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '50546*2',
#     'composerName': 'Granados,  Enrique',
#     'workTitle': 'GOYESCAS',
#     'movement': 'Intermezzo',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '51015*5',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'RUINS OF ATHENS, OP. 113',
#     'movement': 'Marcia alla turca (Turkish march)',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '5347*',
#     'composerName': 'Marquina,  Pasquale',
#     'workTitle': 'ESPAÑA CANI',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '5341*',
#     'composerName': 'Mourant,  Walter',
#     'workTitle': 'VALLEY OF THE MOON',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []}]},
#  {'id': '506acfd8-99c4-4a69-bdb8-bf33aedeb588-0.1',
#   'programID': '1071',
#   'orchestra': 'New York Philharmonic',
#   'season': '1956-57',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1957-05-02T04:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1957-05-03T04:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '2268*',
#     'composerName': 'Berlioz,  Hector',
#     'workTitle': 'CORSAIRE OVERTURE',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '52620*',
#     'composerName': 'Walton,  William',
#     'workTitle': 'CONCERTO, CELLO',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Piatigorsky, Gregor',
#       'soloistInstrument': 'Cello',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '5476*',
#     'composerName': 'Dallapiccola,  Luigi',
#     'workTitle': 'TARTINIANA',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Corigliano, John, Sr.',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'A'}]},
#    {'ID': '52575*',
#     'composerName': 'Mendelssohn,  Felix',
#     'workTitle': 'SYMPHONY NO. 3, A MINOR, OP.56 (SCOTTISH)',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': '96d417ba-8630-472c-acb6-99c1408ae943-0.1',
#   'programID': '1082',
#   'orchestra': 'New York Philharmonic',
#   'season': '1956-57',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1957-05-05T04:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '5481*',
#     'composerName': 'Sherwood,  Gordon',
#     'workTitle': 'INTRODUCTION AND ALLEGRO',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '52456*',
#     'composerName': 'Beethoven,  Ludwig  van',
#     'workTitle': 'SYMPHONY NO. 8 IN F MAJOR, OP.93',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '52620*',
#     'composerName': 'Walton,  William',
#     'workTitle': 'CONCERTO, CELLO',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Piatigorsky, Gregor',
#       'soloistInstrument': 'Cello',
#       'soloistRoles': 'S'}]},
#    {'ID': '54103*',
#     'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#     'workTitle': 'CAPRICCIO ITALIEN, OP.45',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []}]},
#  {'id': '506a2096-f685-4fde-b967-fdb76bfbfa9e-0.1',
#   'programID': '1086',
#   'orchestra': 'New York Philharmonic',
#   'season': '1956-57',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1957-05-09T04:00:00Z',
#     'Time': '8:45PM'},
#    {'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1957-05-10T04:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '5485*',
#     'composerName': 'Bentzon,  Niels  Viggo',
#     'workTitle': 'VARIAZIONI BREVI, OP.75',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': []},
#    {'ID': '50867*',
#     'composerName': 'Kodaly [Kodály],  Zoltán',
#     'workTitle': 'PSALMUS HUNGARICUS',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Lloyd, David',
#       'soloistInstrument': 'Tenor',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Schola Cantorum of NY',
#       'soloistInstrument': 'Chorus',
#       'soloistRoles': 'S'}]},
#    {'ID': '5489*',
#     'composerName': 'Foss,  Lukas',
#     'workTitle': 'PSALMS',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Schola Cantorum of NY',
#       'soloistInstrument': 'Chorus',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '52089*',
#     'composerName': 'Walton,  William',
#     'workTitle': "BELSHAZZAR'S FEAST",
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Tozzi, Giorgio',
#       'soloistInstrument': 'Bass',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Schola Cantorum of NY',
#       'soloistInstrument': 'Chorus',
#       'soloistRoles': 'S'}]}]},
#  {'id': '1d1a3d5c-ca6c-4a71-8ae1-fd508712c326-0.1',
#   'programID': '1089',
#   'orchestra': 'New York Philharmonic',
#   'season': '1956-57',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1957-05-12T04:00:00Z',
#     'Time': '2:30PM'}],
#   'works': [{'ID': '50867*',
#     'composerName': 'Kodaly [Kodály],  Zoltán',
#     'workTitle': 'PSALMUS HUNGARICUS',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Lloyd, David',
#       'soloistInstrument': 'Tenor',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Schola Cantorum of NY',
#       'soloistInstrument': 'Chorus',
#       'soloistRoles': 'S'}]},
#    {'ID': '5489*',
#     'composerName': 'Foss,  Lukas',
#     'workTitle': 'PSALMS',
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Schola Cantorum of NY',
#       'soloistInstrument': 'Chorus',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '52089*',
#     'composerName': 'Walton,  William',
#     'workTitle': "BELSHAZZAR'S FEAST",
#     'conductorName': 'Mitropoulos, Dimitri',
#     'soloists': [{'soloistName': 'Tozzi, Giorgio',
#       'soloistInstrument': 'Bass',
#       'soloistRoles': 'S'},
#      {'soloistName': 'Schola Cantorum of NY',
#       'soloistInstrument': 'Chorus',
#       'soloistRoles': 'S'}]}]},
#  {'id': '6a0f1cff-6141-4e1b-8921-b7bf3fab22f9-0.1',
#   'programID': '4642',
#   'orchestra': 'New York Philharmonic',
#   'season': '1958-59',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1959-01-11T05:00:00Z',
#     'Time': '3:00PM'}],
#   'works': [{'ID': '51075*',
#     'composerName': 'Barbirolli,  John',
#     'workTitle': 'ELIZABETHAN SUITE',
#     'conductorName': 'Barbirolli , John',
#     'soloists': []},
#    {'ID': '52098*',
#     'composerName': 'Walton,  William',
#     'workTitle': 'CONCERTO, VIOLIN',
#     'conductorName': 'Barbirolli , John',
#     'soloists': [{'soloistName': 'Corigliano, John, Sr.',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '52826*',
#     'composerName': 'Mahler,  Gustav',
#     'workTitle': 'SYMPHONY NO.  1 IN D MAJOR (TITAN)',
#     'conductorName': 'Barbirolli , John',
#     'soloists': []}]},
#  {'id': '72ffd803-2417-4962-847d-a7684f575955-0.1',
#   'programID': '4861',
#   'orchestra': 'New York Philharmonic',
#   'season': '1959-60',
#   'concerts': [{'eventType': 'Subscription Season',
#     'Location': 'Manhattan, NY',
#     'Venue': 'Carnegie Hall',
#     'Date': '1959-11-29T05:00:00Z',
#     'Time': '8:15PM'}],
#   'works': [{'ID': '52076*',
#     'composerName': 'Haydn,  Franz  Joseph',
#     'workTitle': 'SYMPHONY NO.  88, G MAJOR',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '4069*',
#     'composerName': 'Puccini,  Giacomo',
#     'workTitle': 'CRISANTEMI, I (THE CHRYSANTHEMUMS)',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '50683*',
#     'composerName': 'Walton,  William',
#     'workTitle': 'JOHANNESBURG FESTIVAL OVERTURE',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#    {'ID': '52638*2',
#     'composerName': 'Debussy,  Claude',
#     'workTitle': 'NOCTURNES',
#     'movement': 'Fêtes ("Festivals")',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '3812*',
#     'composerName': 'Ravel,  Maurice',
#     'workTitle': 'TZIGANE',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': [{'soloistName': 'Corigliano, John, Sr.',
#       'soloistInstrument': 'Violin',
#       'soloistRoles': 'S'}]},
#    {'ID': '3077*',
#     'composerName': 'Offenbach,  Jacques',
#     'workTitle': 'GAITE PARISIENNE (ARR. Rosenthal)',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '4450*',
#     'composerName': 'Debussy,  Claude',
#     'workTitle': 'REVERIE',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '2856*8',
#     'composerName': 'Gounod,  Charles',
#     'workTitle': 'FAUST',
#     'movement': 'Waltz',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '4461*',
#     'composerName': 'Debussy,  Claude',
#     'workTitle': 'GIRL WITH THE FLAXEN HAIR, THE (ORCH) (ARR. Unspecified)',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []},
#    {'ID': '8865*1',
#     'composerName': 'Offenbach,  Jacques',
#     'workTitle': 'ORPHEUS IN THE UNDERWORLD',
#     'movement': 'Can-Can',
#     'conductorName': 'Kostelanetz, Andre',
#     'soloists': []}]}]

# %%
from itertools import pairwise
import pyperclip
import io

seasons = [f'{y1}-{y2-1900}' for y1, y2 in pairwise(range(1960, 1982))]

with io.StringIO() as fp:
    fp.write("[")
    for season in seasons:
        fp.write(f"'{season}', ")
    s = fp.getvalue().strip()[:-1] + "]"
     
pyperclip.copy(s)

# %%
seasons = {p['season'] for p in all_subscription_programs}

# %%
seasons
# Out:
# {'1955-56',
#  '1956-57',
#  '1957-58',
#  '1958-59',
#  '1959-60',
#  '1960-61',
#  '1961-62',
#  '1962-63'}

# %%
subscription_programs = {}
subscription_programs['1960-63'] = [p for p in all_subscription_programs
                                    if p['season'] in SEASONS]
len(subscription_programs['1960-63'])
# Out:
# 123
